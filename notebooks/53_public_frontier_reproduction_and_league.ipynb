# %% [markdown]
# # Kaggriculture — hash-pinned public-frontier reproduction and broad league
# ## Objective
# Test a structurally different, complete full-season production policy instead of another narrow timing or terminal overlay. The candidate is the exact SHA-256-pinned `V16-RC5-PremiumMarketLead` controller independently preserved at two immutable public Git commits. Runtime acquisition does not use Kaggle kernel APIs and does not execute notebook cells. The original Kaggle page reported a 2,913.3 best score for V2; the exact source hash-to-score binding remains provenance context rather than an experimental claim.
#
# The current verified official baseline remains the stronger of the user's two live submissions. This notebook does not equate local cash or win rate with Kaggle rating, does not claim authorship of the public controller, and cannot submit anything.
#
# ## Why this experiment
# Recent sale-order learning, terminal planning, and simple worker-reassignment directions were rejected. The production forensic study found different loss mechanisms across time and submissions, so a micro-patch was not justified. The new capability is a full-season 8-cow/4-sheep premium-market production architecture evaluated against **both** live-source policies and a fixed three-opponent field.
#
# ## Frozen evaluation
# The direct panel uses 16 prespecified seeds and both seats against each live-source baseline. The field panel uses eight different seeds, both seats, and the same three public opponents for the candidate and both baselines. The unit of uncertainty is a seed cluster (and opponent-seed cluster in the field), not an individual seat. The field runs only after both direct comparisons qualify. A pass is nomination for separate confirmation, not deployment.

# %%
import json
import plotly.graph_objects as go
from IPython.display import display
DATA=json.loads('{"candidate":{"base_ref":"boatlee/v16-rc5-high-score-8c-4s-premium-market-lead","bytes":18946,"exact_hash_to_reported_v2_score_established":false,"expected_sha256":"f029fa0cb66a9eb509afbe44e3f59b800332d0419db91607183410e4089c4d19","full_upstream_optimizer_recreated":false,"id":"boatlee_v16_f029fa0c","kind":"runtime_public_reference","license_evidence":"Apache-2.0 reported by the original public Kaggle notebook page; attribution retained in receipt and project notices.","network_downloads":1,"receipt_path":"/home/sagemaker-user/.cache/kaggriculture_public_frontier/sources/boatlee_v16_f029fa0c/receipt.json","receipt_sha256":"ddad2a80b43d0becf3b144815022aff7277d07efd045d2d86e31536b58dc4209","ref":"boatlee/v16-rc5-high-score-8c-4s-premium-market-lead","reported_notebook_sha256":"92faf3269de09bdf8bcbb3d306f12cf8a8d83385e9cec94b78f6134a04d4143f","reused":false,"sha256":"f029fa0cb66a9eb509afbe44e3f59b800332d0419db91607183410e4089c4d19","source_binding":"immutable_git_mirror_exact_hash","source_commit":"145be016edc48f6a41553195fc32ca519ff9353c","source_path":"opponents/v16_rc5_high_score_8c_4s_premium_market_lead.py","source_repository":"sota1111/erl-kaggriculture"},"daily_pairs":[{"daily":[{"mean_margin":-12.0,"step":24},{"mean_margin":-106.0,"step":48},{"mean_margin":-211.0,"step":72},{"mean_margin":-251.53125,"step":96},{"mean_margin":-308.0,"step":120},{"mean_margin":-781.53125,"step":144},{"mean_margin":-1031.34375,"step":168},{"mean_margin":390.5625,"step":192},{"mean_margin":-796.84375,"step":216},{"mean_margin":-478.25,"step":240},{"mean_margin":-12068.5625,"step":264},{"mean_margin":-9754.9375,"step":288},{"mean_margin":-11526.84375,"step":312},{"mean_margin":-12379.875,"step":336},{"mean_margin":-15927.96875,"step":360},{"mean_margin":-18507.21875,"step":384},{"mean_margin":-19880.28125,"step":408},{"mean_margin":-23137.03125,"step":432},{"mean_margin":-22050.09375,"step":456},{"mean_margin":-22947.75,"step":480},{"mean_margin":-18881.21875,"step":504},{"mean_margin":-19853.3125,"step":528},{"mean_margin":-20924.59375,"step":552},{"mean_margin":-23038.71875,"step":576},{"mean_margin":-23561.78125,"step":600},{"mean_margin":-24930.09375,"step":624},{"mean_margin":-26657.28125,"step":648},{"mean_margin":-26387.0,"step":672},{"mean_margin":-31212.125,"step":696},{"mean_margin":-34572.15625,"step":719}],"label":"boatlee_v16_f029fa0c vs sale_timing"},{"daily":[{"mean_margin":-14.0,"step":24},{"mean_margin":-108.0,"step":48},{"mean_margin":-213.0,"step":72},{"mean_margin":-346.0,"step":96},{"mean_margin":-401.1875,"step":120},{"mean_margin":-889.875,"step":144},{"mean_margin":-1313.1875,"step":168},{"mean_margin":288.5,"step":192},{"mean_margin":-1027.125,"step":216},{"mean_margin":-1141.9375,"step":240},{"mean_margin":-12432.875,"step":264},{"mean_margin":-10492.875,"step":288},{"mean_margin":-12952.9375,"step":312},{"mean_margin":-13106.125,"step":336},{"mean_margin":-16478.0,"step":360},{"mean_margin":-17932.1875,"step":384},{"mean_margin":-19925.6875,"step":408},{"mean_margin":-24159.6875,"step":432},{"mean_margin":-22469.59375,"step":456},{"mean_margin":-23154.1875,"step":480},{"mean_margin":-19298.875,"step":504},{"mean_margin":-20071.1875,"step":528},{"mean_margin":-22084.84375,"step":552},{"mean_margin":-23681.53125,"step":576},{"mean_margin":-23952.3125,"step":600},{"mean_margin":-24783.40625,"step":624},{"mean_margin":-26503.78125,"step":648},{"mean_margin":-26557.625,"step":672},{"mean_margin":-31726.46875,"step":696},{"mean_margin":-34648.0,"step":719}],"label":"boatlee_v16_f029fa0c vs timing_current"}],"decision":{"archive":{"byte_identical":false,"official_loader_callback":null,"status":"NOT_BUILT_CANDIDATE_NOT_QUALIFIED"},"direct":{"comparisons":[{"agent":"boatlee_v16_f029fa0c","cash_95_seed_bootstrap":[-43248.28515625,-26853.33359375],"clusters":[{"margin":-54445.0,"score":0.0,"seed":1609226101},{"margin":-19416.0,"score":0.0,"seed":1609226102},{"margin":-45855.0,"score":0.0,"seed":1609226103},{"margin":-40212.0,"score":0.0,"seed":1609226104},{"margin":-62444.0,"score":0.0,"seed":1609226105},{"margin":-33545.0,"score":0.0,"seed":1609226106},{"margin":-35582.0,"score":0.0,"seed":1609226107},{"margin":-72140.0,"score":0.0,"seed":1609226108},{"margin":-14752.0,"score":0.0,"seed":1609226109},{"margin":-32534.0,"score":0.0,"seed":1609226110},{"margin":-15310.0,"score":0.0,"seed":1609226111},{"margin":-19891.0,"score":0.0,"seed":1609226112},{"margin":-19034.5,"score":0.0,"seed":1609226113},{"margin":-23065.0,"score":0.0,"seed":1609226114},{"margin":-41101.0,"score":0.0,"seed":1609226115},{"margin":-23828.0,"score":0.0,"seed":1609226116}],"games":32,"losses":32,"mean_cash_margin":-34572.15625,"opponent":"sale_timing","passed":false,"score":0.0,"seat_scores":{"0":0.0,"1":0.0},"seed_clusters":16,"sign_p_one_sided":1.0,"successful_seeds":0,"ties":0,"win_tie_95_seed_bootstrap":[0.0,0.0],"wins":0},{"agent":"boatlee_v16_f029fa0c","cash_95_seed_bootstrap":[-43251.7046875,-26893.921875],"clusters":[{"margin":-62689.0,"score":0.0,"seed":1609226101},{"margin":-18966.0,"score":0.0,"seed":1609226102},{"margin":-44722.0,"score":0.0,"seed":1609226103},{"margin":-39767.0,"score":0.0,"seed":1609226104},{"margin":-62313.0,"score":0.0,"seed":1609226105},{"margin":-32745.0,"score":0.0,"seed":1609226106},{"margin":-35506.0,"score":0.0,"seed":1609226107},{"margin":-68593.0,"score":0.0,"seed":1609226108},{"margin":-15239.0,"score":0.0,"seed":1609226109},{"margin":-31624.0,"score":0.0,"seed":1609226110},{"margin":-15923.0,"score":0.0,"seed":1609226111},{"margin":-18955.0,"score":0.0,"seed":1609226112},{"margin":-20406.0,"score":0.0,"seed":1609226113},{"margin":-22102.0,"score":0.0,"seed":1609226114},{"margin":-40612.0,"score":0.0,"seed":1609226115},{"margin":-24206.0,"score":0.0,"seed":1609226116}],"games":32,"losses":32,"mean_cash_margin":-34648.0,"opponent":"timing_current","passed":false,"score":0.0,"seat_scores":{"0":0.0,"1":0.0},"seed_clusters":16,"sign_p_one_sided":1.0,"successful_seeds":0,"ties":0,"win_tie_95_seed_bootstrap":[0.0,0.0],"wins":0}],"games":64,"passed":false,"rules":{"bootstrap_replicates":10000,"bootstrap_rng_seed":921713,"decision_scope":"Nomination for separate untouched confirmation only. No automatic submission.","direct_cash_bootstrap_lower_min_exclusive":0.0,"direct_each_seat_min":0.5,"direct_score_min":0.625,"direct_sign_p_max":0.05,"field_opponent_delta_floor":-0.05,"field_over_best_baseline_min":0.05,"field_relative_cash_bootstrap_lower_min_exclusive":0.0,"field_seat_delta_floor":-0.05,"sampling_limit":"Prespecified engineering seeds and fixed public opponents are not a probability sample of the live ladder."},"status":"DIRECT_REJECT"},"field":null,"fits":0,"interpretation":"A nomination is local evidence for a separate confirmation. It is not an official-rating claim and does not alter either current submission.","qualified":false,"status":"DIRECT_REJECT_KEEP_CURRENT_SUBMISSIONS","submission_attempted":false},"direct":{"comparisons":[{"agent":"boatlee_v16_f029fa0c","cash_95_seed_bootstrap":[-43248.28515625,-26853.33359375],"clusters":[{"margin":-54445.0,"score":0.0,"seed":1609226101},{"margin":-19416.0,"score":0.0,"seed":1609226102},{"margin":-45855.0,"score":0.0,"seed":1609226103},{"margin":-40212.0,"score":0.0,"seed":1609226104},{"margin":-62444.0,"score":0.0,"seed":1609226105},{"margin":-33545.0,"score":0.0,"seed":1609226106},{"margin":-35582.0,"score":0.0,"seed":1609226107},{"margin":-72140.0,"score":0.0,"seed":1609226108},{"margin":-14752.0,"score":0.0,"seed":1609226109},{"margin":-32534.0,"score":0.0,"seed":1609226110},{"margin":-15310.0,"score":0.0,"seed":1609226111},{"margin":-19891.0,"score":0.0,"seed":1609226112},{"margin":-19034.5,"score":0.0,"seed":1609226113},{"margin":-23065.0,"score":0.0,"seed":1609226114},{"margin":-41101.0,"score":0.0,"seed":1609226115},{"margin":-23828.0,"score":0.0,"seed":1609226116}],"games":32,"losses":32,"mean_cash_margin":-34572.15625,"opponent":"sale_timing","passed":false,"score":0.0,"seat_scores":{"0":0.0,"1":0.0},"seed_clusters":16,"sign_p_one_sided":1.0,"successful_seeds":0,"ties":0,"win_tie_95_seed_bootstrap":[0.0,0.0],"wins":0},{"agent":"boatlee_v16_f029fa0c","cash_95_seed_bootstrap":[-43251.7046875,-26893.921875],"clusters":[{"margin":-62689.0,"score":0.0,"seed":1609226101},{"margin":-18966.0,"score":0.0,"seed":1609226102},{"margin":-44722.0,"score":0.0,"seed":1609226103},{"margin":-39767.0,"score":0.0,"seed":1609226104},{"margin":-62313.0,"score":0.0,"seed":1609226105},{"margin":-32745.0,"score":0.0,"seed":1609226106},{"margin":-35506.0,"score":0.0,"seed":1609226107},{"margin":-68593.0,"score":0.0,"seed":1609226108},{"margin":-15239.0,"score":0.0,"seed":1609226109},{"margin":-31624.0,"score":0.0,"seed":1609226110},{"margin":-15923.0,"score":0.0,"seed":1609226111},{"margin":-18955.0,"score":0.0,"seed":1609226112},{"margin":-20406.0,"score":0.0,"seed":1609226113},{"margin":-22102.0,"score":0.0,"seed":1609226114},{"margin":-40612.0,"score":0.0,"seed":1609226115},{"margin":-24206.0,"score":0.0,"seed":1609226116}],"games":32,"losses":32,"mean_cash_margin":-34648.0,"opponent":"timing_current","passed":false,"score":0.0,"seat_scores":{"0":0.0,"1":0.0},"seed_clusters":16,"sign_p_one_sided":1.0,"successful_seeds":0,"ties":0,"win_tie_95_seed_bootstrap":[0.0,0.0],"wins":0}],"games":64,"passed":false,"rules":{"bootstrap_replicates":10000,"bootstrap_rng_seed":921713,"decision_scope":"Nomination for separate untouched confirmation only. No automatic submission.","direct_cash_bootstrap_lower_min_exclusive":0.0,"direct_each_seat_min":0.5,"direct_score_min":0.625,"direct_sign_p_max":0.05,"field_opponent_delta_floor":-0.05,"field_over_best_baseline_min":0.05,"field_relative_cash_bootstrap_lower_min_exclusive":0.0,"field_seat_delta_floor":-0.05,"sampling_limit":"Prespecified engineering seeds and fixed public opponents are not a probability sample of the live ladder."},"status":"DIRECT_REJECT"},"field":null,"phase":"completed","sources":{"boatlee_v16_f029fa0c":{"bytes":18946,"expected_sha256":"f029fa0cb66a9eb509afbe44e3f59b800332d0419db91607183410e4089c4d19","ref":"boatlee/v16-rc5-high-score-8c-4s-premium-market-lead","sha256":"f029fa0cb66a9eb509afbe44e3f59b800332d0419db91607183410e4089c4d19","source_binding":"immutable_git_mirror_exact_hash","source_commit":"145be016edc48f6a41553195fc32ca519ff9353c","source_repository":"sota1111/erl-kaggriculture"},"farm2945":{"ref":"thomastschinkel/the-2945-farm-96-vs-the-top-10-public-bots","sha256":"bfee70e9daaebeae0737a880f1df8f1c60d0783c59af620136cc0d28ef482bc7"},"farming_v50":{"ref":"lynnsakurai/farming-score-v2-a-better-approach","sha256":"177d78bdf00aa96579d98052558e18cd3081d29f855c8a6f20a2bbfebcdbda11"},"market_shock":{"ref":"dmitriigluzdov/kaggriculture-a-smaller-market-shock","sha256":"d5460fc2e5488e0a340f0e4e795f2709c48b58cff7c204ced3821a4c7dae4555"},"sale_timing":{"ref":"tetsutani/demand-preserving-turn-sale-timing","sha256":"1aa3717b3201997a95920c80cf5612c23f78f8716c7b1084b6a345ca4eae7e4f"},"timing_current":{"ref":"tetsutani/demand-preserving-turn-sale-timing","sha256":"9c0a8921aa49fba080d53deee3c9fe8db7a8e2b02881e9adda4090af73e9c187"}},"submission_attempted":false}')
DIRECT=(DATA.get('decision') or {}).get('direct') or DATA.get('direct') or {}
FIELD=(DATA.get('decision') or {}).get('field') or DATA.get('field') or {}
def show(fig,height=500):
 fig.update_layout(width=1120,height=height,margin=dict(l=90,r=35,t=85,b=100),font=dict(size=14))
 display({'application/vnd.plotly.v1+json':json.loads(fig.to_json())},raw=True)
def pending(fig,text):fig.add_annotation(text=text,x=.5,y=.5,xref='paper',yref='paper',showarrow=False)
print(json.dumps({'phase':DATA.get('phase'),'candidate':DATA.get('candidate',{}).get('ref'),'direct_status':DIRECT.get('status','NOT_RUN'),'field_status':FIELD.get('status','NOT_RUN'),'submission_attempted':False},indent=2))
# Out:
# {
#   "phase": "completed",
#   "candidate": "boatlee/v16-rc5-high-score-8c-4s-premium-market-lead",
#   "direct_status": "DIRECT_REJECT",
#   "field_status": "NOT_RUN",
#   "submission_attempted": false
# }

# %% [markdown]
# ## Source identity and architecture footprint
# Source size is provenance/load information, not a performance metric. The dynamic candidate is bound to the frozen `main.py` SHA-256, an immutable mirror commit and path, and a durable acquisition receipt. A wrong hash or unavailable source stops the run before any games.

# %%
sources=DATA.get('sources',{})
fig=go.Figure(go.Bar(x=[sources[k].get('bytes',0)/1024 for k in sources],y=list(sources),orientation='h',customdata=[sources[k].get('sha256') for k in sources],hovertemplate='%{y}<br>%{x:.1f} KiB<br>%{customdata}<extra></extra>'))
fig.update_layout(title='Exact source artifacts — size and identity, not strength',xaxis_title='Source size (KiB)',yaxis_title='Policy artifact')
show(fig,560)

# %% [markdown]
# ## Direct qualification against both live-source policies
# A win contributes 1, a tie 0.5, and a loss 0. Error bars use whole-seed resampling after averaging the two seats.

# %%
comps=DIRECT.get('comparisons',[]);fig=go.Figure()
for c in comps:
 lo,hi=c['win_tie_95_seed_bootstrap'];fig.add_trace(go.Bar(x=[c['opponent']],y=[c['score']],name=c['opponent'],error_y=dict(type='data',symmetric=False,array=[max(0,hi-c['score'])],arrayminus=[max(0,c['score']-lo)]),customdata=[[c['wins'],c['ties'],c['losses'],c['mean_cash_margin']]],hovertemplate='%{x}<br>score %{y:.3f}<br>W/T/L %{customdata[0]}/%{customdata[1]}/%{customdata[2]}<br>mean cash %{customdata[3]:,.0f}<extra></extra>'))
if not comps:pending(fig,'Direct panel has not completed; this is not a zero result.')
fig.add_hline(y=.625,line_dash='dash');fig.add_hline(y=.5,line_dash='dot');fig.update_layout(title='Candidate versus each current live-source policy',xaxis_title='Baseline policy',yaxis_title='Win–tie score',showlegend=False);fig.update_yaxes(range=[0,1]);show(fig)

# %% [markdown]
# ## Broad fixed-opponent field
# All three policies face identical opponent-seed-seat contexts. This comparison is broader than the previous two-controller confirmation, but the fixed public opponents are still not the live ladder.

# %%
pol=FIELD.get('policies',{});fig=go.Figure()
for name,row in pol.items():
 fig.add_trace(go.Bar(x=[name],y=[row['score']],name=name,error_y=dict(type='data',symmetric=False,array=[max(0,row['win_tie_95_cluster_bootstrap'][1]-row['score'])],arrayminus=[max(0,row['score']-row['win_tie_95_cluster_bootstrap'][0])]),customdata=[[row['mean_cash_margin']]],hovertemplate='%{x}<br>score %{y:.3f}<br>mean cash margin %{customdata[0]:,.0f}<extra></extra>'))
if not pol:pending(fig,'Field panel was not started or has not completed.')
fig.add_hline(y=.5,line_dash='dot');fig.update_layout(title='Matched fixed-opponent field performance',xaxis_title='Policy',yaxis_title='Win–tie score',showlegend=False);fig.update_yaxes(range=[0,1]);show(fig)

# %% [markdown]
# ## When any direct advantage emerges
# The trajectory is descriptive cash evidence from actual closed-loop games. It cannot substitute for win–tie qualification or official rating.

# %%
fig=go.Figure()
for pair in DATA.get('daily_pairs',[]):fig.add_trace(go.Scatter(x=[x['step'] for x in pair['daily']],y=[x['mean_margin'] for x in pair['daily']],mode='lines',name=pair['label']))
if not DATA.get('daily_pairs'):pending(fig,'No completed direct trajectories yet.')
fig.add_hline(y=0,line_dash='dot');fig.update_layout(title='Direct-panel mean cash advantage through the season',xaxis_title='Engine step',yaxis_title='Candidate cash advantage (game currency)',legend=dict(orientation='h',y=-.28));show(fig)

# %% [markdown]
# ## Decision
# A qualifying candidate earns an independent confirmation package only. Failure means this exact public frontier does not qualify under the frozen league; thresholds are not lowered and the two current submissions remain untouched. The detailed return includes source receipts, hashes, checkpoints, game records, action digests, uncertainty calculations, and this notebook.

# %%
assert DATA.get('submission_attempted',False) is False
print('PUBLIC_FRONTIER_NOTEBOOK_COMPLETE')
# Out:
# PUBLIC_FRONTIER_NOTEBOOK_COMPLETE
