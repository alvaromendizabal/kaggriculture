# %% [markdown]
# # 49 · Verified submission feedback and incremental replay data
#
# ## Objective
# Refresh only the missing affordable compact archive snapshot without repeating saved downloads, identify the separate organizer-payload gap, and observe the already-submitted controller **56471163**. The previous reference release already submitted this controller. This continuation observes its official status and eight time-selected public games, reuses the existing compact-archive ingestion, and updates broad metadata within explicit caps. No new submission, training, simulator game, or policy change occurs.
#
# ## Interpretation boundaries
# An index is not the underlying data. A community top-10 subset is not the organizer's complete replay stream. Saved trajectories are not automatically training data, and a local win score is not a Kaggle rating. The public-game sample is selected by time, not outcomes; its descriptive win rate does not estimate the entire ladder.

# %%
import json
import plotly.graph_objects as go
from IPython.display import display
D=json.loads('{"all_competition_data_retained": false, "broad_metadata": {"all_source_payloads_retained": false, "dataset": "georgymamarin/kaggriculture-episodes", "deferred": [{"bytes": 109520907, "creation_date": "2026-09-22 01:51:28.338000", "dataset": "georgymamarin/kaggriculture-episodes", "identity": "a27e7a53b19809d47a341784d4061419b9d1d8455ba0685626dbb9f63045b947", "name": "state.json", "reason": "BOUNDED_METADATA_BUDGET"}], "known_metadata_names_absent": [], "listing_complete": true, "newly_saved": [{"claim": {"bytes": 23482319, "creation_date": "2026-09-22 01:51:27.114000", "dataset": "georgymamarin/kaggriculture-episodes", "identity": "524349d3aea5b66bb328e5e692048fe3b555a9247214c09ce4118525c35d1ea1", "name": "agents.csv"}, "s3_key": "external/frontier_replays/v1/derived/live_feedback_delta_v1/broad_metadata/79ecdcd343e02ac4bc37d2e3038cf1d204baac1f4cf8e69f410ab13ccbb25872/agents.csv", "sha256": "79ecdcd343e02ac4bc37d2e3038cf1d204baac1f4cf8e69f410ab13ccbb25872", "verified_utc": "2026-09-22T18:54:35.379726+00:00"}, {"claim": {"bytes": 2879, "creation_date": "2026-09-22 01:51:26.748000", "dataset": "georgymamarin/kaggriculture-episodes", "identity": "78941b1bd2c98a6c7dd9863dd426ece03f348fb2ef53a6163423611c4ced0726", "name": "daily_stats.csv"}, "s3_key": "external/frontier_replays/v1/derived/live_feedback_delta_v1/broad_metadata/9f44613b3ff76f569c39268a3c659307dd5c2734e5096729d199f7c92b64a9cc/daily_stats.csv", "sha256": "9f44613b3ff76f569c39268a3c659307dd5c2734e5096729d199f7c92b64a9cc", "verified_utc": "2026-09-22T18:54:36.807337+00:00"}, {"claim": {"bytes": 44002138, "creation_date": "2026-09-22 01:51:27.357000", "dataset": "georgymamarin/kaggriculture-episodes", "identity": "df94b82a7a66ff8b2847d31cad2930ef1ecd9c7a9cdbc517402071a7b9e3d3a1", "name": "episode_features.csv"}, "s3_key": "external/frontier_replays/v1/derived/live_feedback_delta_v1/broad_metadata/f9e6d9500457e884ea3597808912c90c3732f7fa70f387ab7cb5624a40b58d6d/episode_features.csv", "sha256": "f9e6d9500457e884ea3597808912c90c3732f7fa70f387ab7cb5624a40b58d6d", "verified_utc": "2026-09-22T18:54:40.245841+00:00"}, {"claim": {"bytes": 39699098, "creation_date": "2026-09-22 01:51:27.783000", "dataset": "georgymamarin/kaggriculture-episodes", "identity": "50bcb6edbdaf29fcfa7e12fac472acf4f97a93346fdf3f028dd98751d87a73a1", "name": "episodes.csv"}, "s3_key": "external/frontier_replays/v1/derived/live_feedback_delta_v1/broad_metadata/a0fad94d47c5f0ac69c9743a0bbb22c1f7b2f9010f87893d7fa61016b3ddaf32/episodes.csv", "sha256": "a0fad94d47c5f0ac69c9743a0bbb22c1f7b2f9010f87893d7fa61016b3ddaf32", "verified_utc": "2026-09-22T18:54:43.452279+00:00"}, {"claim": {"bytes": 1076365, "creation_date": "2026-09-22 01:51:26.837000", "dataset": "georgymamarin/kaggriculture-episodes", "identity": "3f34211770fccb1928ccc96a1def7c1ed5a679f093b035663dfcd6cfdacc1d61", "name": "per_submission_coverage.csv"}, "s3_key": "external/frontier_replays/v1/derived/live_feedback_delta_v1/broad_metadata/804852d0e2beb7055c7eed8079f0188470449da758f474b8688a6d9deabbc2a1/per_submission_coverage.csv", "sha256": "804852d0e2beb7055c7eed8079f0188470449da758f474b8688a6d9deabbc2a1", "verified_utc": "2026-09-22T18:54:45.187647+00:00"}, {"claim": {"bytes": 56215674, "creation_date": "2026-09-22 01:54:44.794000", "dataset": "georgymamarin/kaggriculture-episodes", "identity": "b4ad685ec0be75a16fee617c7d3a5342461bc22b7fca07d72a1e880646488ed6", "name": "stream_hashes.csv"}, "s3_key": "external/frontier_replays/v1/derived/live_feedback_delta_v1/broad_metadata/8b4cd81c978503e597fd6ca3d0d51a2fe6086dabc8583d77cfdcf0ff6133f05a/stream_hashes.csv", "sha256": "8b4cd81c978503e597fd6ca3d0d51a2fe6086dabc8583d77cfdcf0ff6133f05a", "verified_utc": "2026-09-22T18:54:48.470654+00:00"}, {"claim": {"bytes": 540860, "creation_date": "2026-09-22 01:54:44.033000", "dataset": "georgymamarin/kaggriculture-episodes", "identity": "0c7d1d1c99d4717fdddb2c5e5b3f40d50a33237bb5332b19bbf7105fd2d4a58f", "name": "teams.csv"}, "s3_key": "external/frontier_replays/v1/derived/live_feedback_delta_v1/broad_metadata/9b72288b49de39fd4c709be7d3d567ede787cc9198321d71e037734e13f3500e/teams.csv", "sha256": "9b72288b49de39fd4c709be7d3d567ede787cc9198321d71e037734e13f3500e", "verified_utc": "2026-09-22T18:54:50.006208+00:00"}], "raw_large_shards_downloaded": false, "reused": []}, "checkpoint_updated_utc": "2026-09-22T18:54:51.518835+00:00", "coverage": {"all_listed_compact_files_retained": true, "errors": [], "metadata": {"all_official_payloads_retained": false, "announcements_completeness_verified": false, "compact_days": 53, "compact_latest": "2026-09-20", "compact_listing_complete": true, "compact_manifest": {"local": "/home/sagemaker-user/.kaggriculture_live_feedback_20260922T185337139777Z_work/compact_manifest_archive_manifest.json", "s3_key": "external/frontier_replays/v1/derived/frontier_delta_v1/metadata/1d993d4c33d3f2b21cff894fdc77639ca49840f134c6742fb6eabb73212aebc0/compact_manifest/archive_manifest.json", "sha256": "1d993d4c33d3f2b21cff894fdc77639ca49840f134c6742fb6eabb73212aebc0"}, "listed_without_manifest": [], "official_days": 54, "official_index": {"local": "/home/sagemaker-user/.kaggriculture_live_feedback_20260922T185337139777Z_work/official_index_manifest.csv", "s3_key": "external/frontier_replays/v1/derived/frontier_delta_v1/metadata/2a9c7911be2463a196cbe9f733e0239394d1e503a84a28de4cddc050aab81a17/official_index/manifest.csv", "sha256": "2a9c7911be2463a196cbe9f733e0239394d1e503a84a28de4cddc050aab81a17"}, "official_latest": "2026-09-21", "official_reported_bytes": 1150987125747}, "missing_after": [], "newly_saved": [{"bytes": 24380, "date": null, "kind": "metadata", "local_sha256": "50e83161967e04da1575d72575d32c35643eadcbe1c6c731de9950ddfb0b1ee9", "name": "top10_history.parquet", "s3_key": "external/frontier_replays/v1/derived/frontier_delta_v1/metadata/50e83161967e04da1575d72575d32c35643eadcbe1c6c731de9950ddfb0b1ee9/compact_metadata/top10_history.parquet", "sha256": "50e83161967e04da1575d72575d32c35643eadcbe1c6c731de9950ddfb0b1ee9", "verified_utc": "2026-09-22T18:54:20.973357+00:00"}, {"bytes": 48515, "date": null, "kind": "metadata", "local_sha256": "0c913527ef40f37376dac7edf6b5d09159c6d1109e36eb86bad69cd33006baa4", "name": "processed_days.json", "s3_key": "external/frontier_replays/v1/derived/frontier_delta_v1/metadata/0c913527ef40f37376dac7edf6b5d09159c6d1109e36eb86bad69cd33006baa4/compact_metadata/processed_days.json", "sha256": "0c913527ef40f37376dac7edf6b5d09159c6d1109e36eb86bad69cd33006baa4", "verified_utc": "2026-09-22T18:54:22.235211+00:00"}, {"bytes": 2130790, "date": null, "kind": "metadata", "local_sha256": "05ecbff0e3dae8263d8951a93a79eed2b0d66ad4f4fe17154575e4117908dcb4", "name": "episodes.parquet", "s3_key": "external/frontier_replays/v1/derived/frontier_delta_v1/metadata/05ecbff0e3dae8263d8951a93a79eed2b0d66ad4f4fe17154575e4117908dcb4/compact_metadata/episodes.parquet", "sha256": "05ecbff0e3dae8263d8951a93a79eed2b0d66ad4f4fe17154575e4117908dcb4", "verified_utc": "2026-09-22T18:54:24.006018+00:00"}, {"bytes": 104299805, "date": "2026-09-20", "kind": "daily_replays", "local_sha256": "74c7f4b66dc9e297536dac10035f2e2105aec490423a59b42ed78f4a5812749b", "name": "replays_2026-09-20.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-20.parquet", "sha256": "74c7f4b66dc9e297536dac10035f2e2105aec490423a59b42ed78f4a5812749b", "verified_utc": "2026-09-22T18:54:28.516830+00:00"}], "old_raw_overwritten": false, "plan": {"bytes_planned": 106503490, "deferred": [], "missing_before": 4, "retained_before": 52, "selected": [{"bytes": 24380, "date": null, "kind": "metadata", "name": "top10_history.parquet", "s3_key": "external/frontier_replays/v1/derived/frontier_delta_v1/metadata/50e83161967e04da1575d72575d32c35643eadcbe1c6c731de9950ddfb0b1ee9/compact_metadata/top10_history.parquet", "sha256": "50e83161967e04da1575d72575d32c35643eadcbe1c6c731de9950ddfb0b1ee9"}, {"bytes": 48515, "date": null, "kind": "metadata", "name": "processed_days.json", "s3_key": "external/frontier_replays/v1/derived/frontier_delta_v1/metadata/0c913527ef40f37376dac7edf6b5d09159c6d1109e36eb86bad69cd33006baa4/compact_metadata/processed_days.json", "sha256": "0c913527ef40f37376dac7edf6b5d09159c6d1109e36eb86bad69cd33006baa4"}, {"bytes": 2130790, "date": null, "kind": "metadata", "name": "episodes.parquet", "s3_key": "external/frontier_replays/v1/derived/frontier_delta_v1/metadata/05ecbff0e3dae8263d8951a93a79eed2b0d66ad4f4fe17154575e4117908dcb4/compact_metadata/episodes.parquet", "sha256": "05ecbff0e3dae8263d8951a93a79eed2b0d66ad4f4fe17154575e4117908dcb4"}, {"bytes": 104299805, "date": "2026-09-20", "kind": "daily_replays", "name": "replays_2026-09-20.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-20.parquet", "sha256": "74c7f4b66dc9e297536dac10035f2e2105aec490423a59b42ed78f4a5812749b"}]}, "raw_daily_count": 53, "raw_retained_is_not_trained": true, "recent_delta_processing": [{"date": "2026-09-20", "delta_receipt_exists": false, "sha256": "74c7f4b66dc9e297536dac10035f2e2105aec490423a59b42ed78f4a5812749b"}, {"date": "2026-09-19", "delta_receipt_exists": true, "sha256": "7694966618422e399a1ffa4e2c78f2e18f04851b7cd48955101f1e0156d2ea99"}, {"date": "2026-09-18", "delta_receipt_exists": true, "sha256": "607da26491c9c743df78730c9a7ab4840fafab920f22c3c6711b708459625bc8"}, {"date": "2026-09-17", "delta_receipt_exists": false, "sha256": "f891d52daf547fa55a2927ad9597c4893b6c089e7d24ee555ea8f05f0b95bc17"}], "retained_after": [{"bytes": 104583721, "date": "2026-09-19", "kind": "daily_replays", "name": "replays_2026-09-19.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-19.parquet", "sha256": "7694966618422e399a1ffa4e2c78f2e18f04851b7cd48955101f1e0156d2ea99"}, {"bytes": 110978289, "date": "2026-09-18", "kind": "daily_replays", "name": "replays_2026-09-18.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-18.parquet", "sha256": "607da26491c9c743df78730c9a7ab4840fafab920f22c3c6711b708459625bc8"}, {"bytes": 109488584, "date": "2026-09-17", "kind": "daily_replays", "name": "replays_2026-09-17.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-17.parquet", "sha256": "f891d52daf547fa55a2927ad9597c4893b6c089e7d24ee555ea8f05f0b95bc17"}, {"bytes": 107696516, "date": "2026-09-16", "kind": "daily_replays", "name": "replays_2026-09-16.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-16.parquet", "sha256": "2c7ace36b3ef6c29f6b8d73e8703cc5b5b041be93d0ced5150bf9ea7f95e9a5d"}, {"bytes": 104389943, "date": "2026-09-15", "kind": "daily_replays", "name": "replays_2026-09-15.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-15.parquet", "sha256": "437dc3d3dfaaaa7ccffb2da311c20419f3592580353d17584a0b81f6533f64e6"}, {"bytes": 99647428, "date": "2026-09-14", "kind": "daily_replays", "name": "replays_2026-09-14.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-14.parquet", "sha256": "f5f43774f558cb348c9120574d1c4c359c45e0ef3dc9b866fa0cb3e6ebaf05a5"}, {"bytes": 104927660, "date": "2026-09-13", "kind": "daily_replays", "name": "replays_2026-09-13.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-13.parquet", "sha256": "02e36a45be19d1acbcb9265fafac6ed0a1e47a43cec1a134b8263019ac67ef54"}, {"bytes": 106183758, "date": "2026-09-12", "kind": "daily_replays", "name": "replays_2026-09-12.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-12.parquet", "sha256": "8453cbd228d7f51898510085d2caa300b42fbd354d1be8ca560c468d282893ea"}, {"bytes": 101646767, "date": "2026-09-11", "kind": "daily_replays", "name": "replays_2026-09-11.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-11.parquet", "sha256": "c944c5b2ceffa0ea712bf120b4a85a5ddbe18d5e81f491bd5565c354e8ebaa93"}, {"bytes": 95675797, "date": "2026-09-10", "kind": "daily_replays", "name": "replays_2026-09-10.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-10.parquet", "sha256": "968fcc9879caaee77cf5fac0f6b1c233d24c7bd94e547af885969f5229aa5f63"}, {"bytes": 73811453, "date": "2026-09-09", "kind": "daily_replays", "name": "replays_2026-09-09.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-09.parquet", "sha256": "b6551bc63910f17b46c6dff48a7022b74cc5c38229762a05c4a30c3943b5d1c6"}, {"bytes": 90501690, "date": "2026-09-08", "kind": "daily_replays", "name": "replays_2026-09-08.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-08.parquet", "sha256": "d44793b715b7d16fefe41369cf4d81d8641e0e26d30d43eb141859f79d927e9e"}, {"bytes": 96692246, "date": "2026-09-07", "kind": "daily_replays", "name": "replays_2026-09-07.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-07.parquet", "sha256": "ae7f6bc4a2d2775f403226b4dd11fd32d3bfbe00cf35d18867fd6eb0528c83e3"}, {"bytes": 97807481, "date": "2026-09-06", "kind": "daily_replays", "name": "replays_2026-09-06.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-06.parquet", "sha256": "667264f8a6c0369500d402042d48a424170860c417b6fb0ec84aa912e2906945"}, {"bytes": 90709955, "date": "2026-09-05", "kind": "daily_replays", "name": "replays_2026-09-05.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-05.parquet", "sha256": "21a6235667641dc2f75e9bd34b45f5720bcfed0bc58347696657419c476780bd"}, {"bytes": 93848050, "date": "2026-09-04", "kind": "daily_replays", "name": "replays_2026-09-04.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-04.parquet", "sha256": "2159aa6fbc9284ebb339c63c92b48e0ec646f53d51ba0187c8d58b26ef6912b4"}, {"bytes": 80946956, "date": "2026-09-03", "kind": "daily_replays", "name": "replays_2026-09-03.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-03.parquet", "sha256": "88733d727b1d25b0ed39c42844f72ed3f5193fefb31efc6be7e5a022f04443ba"}, {"bytes": 74448406, "date": "2026-09-02", "kind": "daily_replays", "name": "replays_2026-09-02.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-02.parquet", "sha256": "27d25f1b3552bbd1d20144ad4ebb37d2a1a43db5ae126de69c4f7d5c4a41ecab"}, {"bytes": 78826972, "date": "2026-09-01", "kind": "daily_replays", "name": "replays_2026-09-01.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-01.parquet", "sha256": "9daf0eb02ca45094af3ea5036019a69a23aa704b4ce1d377a6e3ff2fbc4f8e1d"}, {"bytes": 38052012, "date": "2026-08-31", "kind": "daily_replays", "name": "replays_2026-08-31.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-31.parquet", "sha256": "e6fe411adfcc13aa57f361f4f31685f2d0afed314e386277dbe5d7938e0ec574"}, {"bytes": 45758858, "date": "2026-08-30", "kind": "daily_replays", "name": "replays_2026-08-30.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-30.parquet", "sha256": "3e754bdb474e3358ede66613e33b216e02aabb4487d1ada0872d9daa5855bb60"}, {"bytes": 51599794, "date": "2026-08-29", "kind": "daily_replays", "name": "replays_2026-08-29.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-29.parquet", "sha256": "25453800fe80297cab3d0058abb1c2178e3446fda1b61b80d301141e37ad67e0"}, {"bytes": 42590367, "date": "2026-08-28", "kind": "daily_replays", "name": "replays_2026-08-28.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-28.parquet", "sha256": "9ba10e83159f01afadc6592ebae63af1dc56cfaf35d55892ce206b354c2f8a9e"}, {"bytes": 50189216, "date": "2026-08-27", "kind": "daily_replays", "name": "replays_2026-08-27.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-27.parquet", "sha256": "35337917e222bc0f6663dfbcff62eafd40bdfbca79c51bdc6f3795f1b2e64931"}, {"bytes": 42769052, "date": "2026-08-26", "kind": "daily_replays", "name": "replays_2026-08-26.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-26.parquet", "sha256": "1ed9e597d1253ed22c2df19b4b365343c319b40ae090182b1741ba057955b1f0"}, {"bytes": 38130015, "date": "2026-08-25", "kind": "daily_replays", "name": "replays_2026-08-25.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-25.parquet", "sha256": "791e896ec4d2ae683baa064bea2178d60671f29c47a61905a1c0141d3d73aee0"}, {"bytes": 39390535, "date": "2026-08-24", "kind": "daily_replays", "name": "replays_2026-08-24.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-24.parquet", "sha256": "bcc12386097044ef7e9c88b4791e765316d5b76d367c27abeb43ee03f9bea953"}, {"bytes": 55867269, "date": "2026-08-23", "kind": "daily_replays", "name": "replays_2026-08-23.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-23.parquet", "sha256": "8a1f51479dbd71c362d226c944021d15cd5e620f5b6b3738b6e16510268d34e1"}, {"bytes": 56683696, "date": "2026-08-22", "kind": "daily_replays", "name": "replays_2026-08-22.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-22.parquet", "sha256": "270c27e64b75999464325cb983747082d51274c4ca61458aae3b1dc592e9a6ed"}, {"bytes": 54639557, "date": "2026-08-21", "kind": "daily_replays", "name": "replays_2026-08-21.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-21.parquet", "sha256": "cc9a5655263691f63ff4a6d4e93ced8d5fe033e959f8f8aafd999fb369caef18"}, {"bytes": 48089441, "date": "2026-08-20", "kind": "daily_replays", "name": "replays_2026-08-20.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-20.parquet", "sha256": "62cff77ab4d41d515422a2546ac08c8a571d4882fb7cb8253d0e1712c1e7c380"}, {"bytes": 53373427, "date": "2026-08-19", "kind": "daily_replays", "name": "replays_2026-08-19.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-19.parquet", "sha256": "11ae4a8eede12d7f658d0c1e6fcbe9b697890cc42206da9280e145199877f3fc"}, {"bytes": 42928204, "date": "2026-08-18", "kind": "daily_replays", "name": "replays_2026-08-18.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-18.parquet", "sha256": "0aedf432034c7b21d4533e70d5ec6bfa92e6fccbdaa567818e57df501b1dee76"}, {"bytes": 62522096, "date": "2026-08-17", "kind": "daily_replays", "name": "replays_2026-08-17.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-17.parquet", "sha256": "09d5a11f1845779c179c8bd743d6d66283c1dc5f866f477a5d43e9616332f800"}, {"bytes": 61483789, "date": "2026-08-16", "kind": "daily_replays", "name": "replays_2026-08-16.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-16.parquet", "sha256": "f5ff68c2f33cac5725221cc6e077e12ef0547e31606785403c0e70d9e8071d68"}, {"bytes": 67393391, "date": "2026-08-15", "kind": "daily_replays", "name": "replays_2026-08-15.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-15.parquet", "sha256": "674bde527eb943d0c86d1613b35ba3a690435d3574119c11d4a4df87bd1a62a5"}, {"bytes": 47969571, "date": "2026-08-14", "kind": "daily_replays", "name": "replays_2026-08-14.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-14.parquet", "sha256": "95e5bd27a2c54641a2d421d21640ddecd14357875a45f490b627b2bf89fdb42b"}, {"bytes": 42042053, "date": "2026-08-13", "kind": "daily_replays", "name": "replays_2026-08-13.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-13.parquet", "sha256": "de76938d8b4e19d07ae5484b29adcbef3753bf9a60412f60ca6749d784ea97af"}, {"bytes": 45792559, "date": "2026-08-12", "kind": "daily_replays", "name": "replays_2026-08-12.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-12.parquet", "sha256": "930b93833f1dcc186ad0299c6018ad2773d7077c73b21159f71e50d671648018"}, {"bytes": 45321223, "date": "2026-08-11", "kind": "daily_replays", "name": "replays_2026-08-11.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-11.parquet", "sha256": "e9d8a375be2d4dbf85b2e44f3f3415f3f62177e1616af68be985d3200df3304c"}, {"bytes": 42987550, "date": "2026-08-10", "kind": "daily_replays", "name": "replays_2026-08-10.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-10.parquet", "sha256": "74fda300d12c457649510c83c01617d814677875cd6776402fe462558bfdfcf6"}, {"bytes": 47538613, "date": "2026-08-09", "kind": "daily_replays", "name": "replays_2026-08-09.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-09.parquet", "sha256": "85797b2ef1baa35cdafde037c619aba79d6d81ff3290f0dc0ea9053f782d9624"}, {"bytes": 34893948, "date": "2026-08-08", "kind": "daily_replays", "name": "replays_2026-08-08.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-08.parquet", "sha256": "559c3f82f7a0967079b0e69e0dd07ff3e44ddcaf34f54ed219f7b1c7e692011a"}, {"bytes": 34200270, "date": "2026-08-07", "kind": "daily_replays", "name": "replays_2026-08-07.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-07.parquet", "sha256": "528f647a5aff18b0a7edab5da507d55721542622ed8d5065b0ffc47f94706545"}, {"bytes": 36694501, "date": "2026-08-06", "kind": "daily_replays", "name": "replays_2026-08-06.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-06.parquet", "sha256": "986cea6e85d1bbd1bd028943bd1028853b663ff784ffcecec9b3418fcf77906b"}, {"bytes": 35651661, "date": "2026-08-05", "kind": "daily_replays", "name": "replays_2026-08-05.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-05.parquet", "sha256": "5829f452c7c8530ffdaa06a36aa223d4f3961731062df4dbaeab7866b1509a44"}, {"bytes": 31401967, "date": "2026-08-04", "kind": "daily_replays", "name": "replays_2026-08-04.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-04.parquet", "sha256": "f608b60897132074dd6dc70e6fa6cf01497e43f824c6850f869255c291d5bb48"}, {"bytes": 28647980, "date": "2026-08-03", "kind": "daily_replays", "name": "replays_2026-08-03.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-03.parquet", "sha256": "9a9be60d8d06e12b68c8af5571bf9f1972e2a47765378910093ef73f53d6bb0b"}, {"bytes": 46858722, "date": "2026-08-02", "kind": "daily_replays", "name": "replays_2026-08-02.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-02.parquet", "sha256": "ad88f35194e005e180faaaf67dddb1fabb0489cf69e5386ad696de0ef9af14b3"}, {"bytes": 50965371, "date": "2026-08-01", "kind": "daily_replays", "name": "replays_2026-08-01.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-01.parquet", "sha256": "5724d20ec7f07974d94d9092fd32601fcc5c3fbc0c124ca698e93533fc4bc2aa"}, {"bytes": 56053811, "date": "2026-07-31", "kind": "daily_replays", "name": "replays_2026-07-31.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-07-31.parquet", "sha256": "f58ae9ffeff04e97964b83a674e190799ddf6faec6f357d274e95cf837ad2daf"}, {"bytes": 29352170, "date": "2026-07-30", "kind": "daily_replays", "name": "replays_2026-07-30.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-07-30.parquet", "sha256": "18d36fffebc682741f76eb878a16e4e2e7435e21c71fcb540516f22ea4eac428"}, {"bytes": 24380, "date": null, "kind": "metadata", "local_sha256": "50e83161967e04da1575d72575d32c35643eadcbe1c6c731de9950ddfb0b1ee9", "name": "top10_history.parquet", "s3_key": "external/frontier_replays/v1/derived/frontier_delta_v1/metadata/50e83161967e04da1575d72575d32c35643eadcbe1c6c731de9950ddfb0b1ee9/compact_metadata/top10_history.parquet", "sha256": "50e83161967e04da1575d72575d32c35643eadcbe1c6c731de9950ddfb0b1ee9", "verified_utc": "2026-09-22T18:54:20.973357+00:00"}, {"bytes": 48515, "date": null, "kind": "metadata", "local_sha256": "0c913527ef40f37376dac7edf6b5d09159c6d1109e36eb86bad69cd33006baa4", "name": "processed_days.json", "s3_key": "external/frontier_replays/v1/derived/frontier_delta_v1/metadata/0c913527ef40f37376dac7edf6b5d09159c6d1109e36eb86bad69cd33006baa4/compact_metadata/processed_days.json", "sha256": "0c913527ef40f37376dac7edf6b5d09159c6d1109e36eb86bad69cd33006baa4", "verified_utc": "2026-09-22T18:54:22.235211+00:00"}, {"bytes": 2130790, "date": null, "kind": "metadata", "local_sha256": "05ecbff0e3dae8263d8951a93a79eed2b0d66ad4f4fe17154575e4117908dcb4", "name": "episodes.parquet", "s3_key": "external/frontier_replays/v1/derived/frontier_delta_v1/metadata/05ecbff0e3dae8263d8951a93a79eed2b0d66ad4f4fe17154575e4117908dcb4/compact_metadata/episodes.parquet", "sha256": "05ecbff0e3dae8263d8951a93a79eed2b0d66ad4f4fe17154575e4117908dcb4", "verified_utc": "2026-09-22T18:54:24.006018+00:00"}, {"bytes": 104299805, "date": "2026-09-20", "kind": "daily_replays", "local_sha256": "74c7f4b66dc9e297536dac10035f2e2105aec490423a59b42ed78f4a5812749b", "name": "replays_2026-09-20.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-20.parquet", "sha256": "74c7f4b66dc9e297536dac10035f2e2105aec490423a59b42ed78f4a5812749b", "verified_utc": "2026-09-22T18:54:28.516830+00:00"}], "retained_before": [{"bytes": 104583721, "date": "2026-09-19", "kind": "daily_replays", "name": "replays_2026-09-19.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-19.parquet", "sha256": "7694966618422e399a1ffa4e2c78f2e18f04851b7cd48955101f1e0156d2ea99"}, {"bytes": 110978289, "date": "2026-09-18", "kind": "daily_replays", "name": "replays_2026-09-18.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-18.parquet", "sha256": "607da26491c9c743df78730c9a7ab4840fafab920f22c3c6711b708459625bc8"}, {"bytes": 109488584, "date": "2026-09-17", "kind": "daily_replays", "name": "replays_2026-09-17.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-17.parquet", "sha256": "f891d52daf547fa55a2927ad9597c4893b6c089e7d24ee555ea8f05f0b95bc17"}, {"bytes": 107696516, "date": "2026-09-16", "kind": "daily_replays", "name": "replays_2026-09-16.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-16.parquet", "sha256": "2c7ace36b3ef6c29f6b8d73e8703cc5b5b041be93d0ced5150bf9ea7f95e9a5d"}, {"bytes": 104389943, "date": "2026-09-15", "kind": "daily_replays", "name": "replays_2026-09-15.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-15.parquet", "sha256": "437dc3d3dfaaaa7ccffb2da311c20419f3592580353d17584a0b81f6533f64e6"}, {"bytes": 99647428, "date": "2026-09-14", "kind": "daily_replays", "name": "replays_2026-09-14.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-14.parquet", "sha256": "f5f43774f558cb348c9120574d1c4c359c45e0ef3dc9b866fa0cb3e6ebaf05a5"}, {"bytes": 104927660, "date": "2026-09-13", "kind": "daily_replays", "name": "replays_2026-09-13.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-13.parquet", "sha256": "02e36a45be19d1acbcb9265fafac6ed0a1e47a43cec1a134b8263019ac67ef54"}, {"bytes": 106183758, "date": "2026-09-12", "kind": "daily_replays", "name": "replays_2026-09-12.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-12.parquet", "sha256": "8453cbd228d7f51898510085d2caa300b42fbd354d1be8ca560c468d282893ea"}, {"bytes": 101646767, "date": "2026-09-11", "kind": "daily_replays", "name": "replays_2026-09-11.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-11.parquet", "sha256": "c944c5b2ceffa0ea712bf120b4a85a5ddbe18d5e81f491bd5565c354e8ebaa93"}, {"bytes": 95675797, "date": "2026-09-10", "kind": "daily_replays", "name": "replays_2026-09-10.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-10.parquet", "sha256": "968fcc9879caaee77cf5fac0f6b1c233d24c7bd94e547af885969f5229aa5f63"}, {"bytes": 73811453, "date": "2026-09-09", "kind": "daily_replays", "name": "replays_2026-09-09.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-09.parquet", "sha256": "b6551bc63910f17b46c6dff48a7022b74cc5c38229762a05c4a30c3943b5d1c6"}, {"bytes": 90501690, "date": "2026-09-08", "kind": "daily_replays", "name": "replays_2026-09-08.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-08.parquet", "sha256": "d44793b715b7d16fefe41369cf4d81d8641e0e26d30d43eb141859f79d927e9e"}, {"bytes": 96692246, "date": "2026-09-07", "kind": "daily_replays", "name": "replays_2026-09-07.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-07.parquet", "sha256": "ae7f6bc4a2d2775f403226b4dd11fd32d3bfbe00cf35d18867fd6eb0528c83e3"}, {"bytes": 97807481, "date": "2026-09-06", "kind": "daily_replays", "name": "replays_2026-09-06.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-06.parquet", "sha256": "667264f8a6c0369500d402042d48a424170860c417b6fb0ec84aa912e2906945"}, {"bytes": 90709955, "date": "2026-09-05", "kind": "daily_replays", "name": "replays_2026-09-05.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-05.parquet", "sha256": "21a6235667641dc2f75e9bd34b45f5720bcfed0bc58347696657419c476780bd"}, {"bytes": 93848050, "date": "2026-09-04", "kind": "daily_replays", "name": "replays_2026-09-04.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-04.parquet", "sha256": "2159aa6fbc9284ebb339c63c92b48e0ec646f53d51ba0187c8d58b26ef6912b4"}, {"bytes": 80946956, "date": "2026-09-03", "kind": "daily_replays", "name": "replays_2026-09-03.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-03.parquet", "sha256": "88733d727b1d25b0ed39c42844f72ed3f5193fefb31efc6be7e5a022f04443ba"}, {"bytes": 74448406, "date": "2026-09-02", "kind": "daily_replays", "name": "replays_2026-09-02.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-02.parquet", "sha256": "27d25f1b3552bbd1d20144ad4ebb37d2a1a43db5ae126de69c4f7d5c4a41ecab"}, {"bytes": 78826972, "date": "2026-09-01", "kind": "daily_replays", "name": "replays_2026-09-01.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-09-01.parquet", "sha256": "9daf0eb02ca45094af3ea5036019a69a23aa704b4ce1d377a6e3ff2fbc4f8e1d"}, {"bytes": 38052012, "date": "2026-08-31", "kind": "daily_replays", "name": "replays_2026-08-31.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-31.parquet", "sha256": "e6fe411adfcc13aa57f361f4f31685f2d0afed314e386277dbe5d7938e0ec574"}, {"bytes": 45758858, "date": "2026-08-30", "kind": "daily_replays", "name": "replays_2026-08-30.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-30.parquet", "sha256": "3e754bdb474e3358ede66613e33b216e02aabb4487d1ada0872d9daa5855bb60"}, {"bytes": 51599794, "date": "2026-08-29", "kind": "daily_replays", "name": "replays_2026-08-29.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-29.parquet", "sha256": "25453800fe80297cab3d0058abb1c2178e3446fda1b61b80d301141e37ad67e0"}, {"bytes": 42590367, "date": "2026-08-28", "kind": "daily_replays", "name": "replays_2026-08-28.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-28.parquet", "sha256": "9ba10e83159f01afadc6592ebae63af1dc56cfaf35d55892ce206b354c2f8a9e"}, {"bytes": 50189216, "date": "2026-08-27", "kind": "daily_replays", "name": "replays_2026-08-27.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-27.parquet", "sha256": "35337917e222bc0f6663dfbcff62eafd40bdfbca79c51bdc6f3795f1b2e64931"}, {"bytes": 42769052, "date": "2026-08-26", "kind": "daily_replays", "name": "replays_2026-08-26.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-26.parquet", "sha256": "1ed9e597d1253ed22c2df19b4b365343c319b40ae090182b1741ba057955b1f0"}, {"bytes": 38130015, "date": "2026-08-25", "kind": "daily_replays", "name": "replays_2026-08-25.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-25.parquet", "sha256": "791e896ec4d2ae683baa064bea2178d60671f29c47a61905a1c0141d3d73aee0"}, {"bytes": 39390535, "date": "2026-08-24", "kind": "daily_replays", "name": "replays_2026-08-24.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-24.parquet", "sha256": "bcc12386097044ef7e9c88b4791e765316d5b76d367c27abeb43ee03f9bea953"}, {"bytes": 55867269, "date": "2026-08-23", "kind": "daily_replays", "name": "replays_2026-08-23.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-23.parquet", "sha256": "8a1f51479dbd71c362d226c944021d15cd5e620f5b6b3738b6e16510268d34e1"}, {"bytes": 56683696, "date": "2026-08-22", "kind": "daily_replays", "name": "replays_2026-08-22.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-22.parquet", "sha256": "270c27e64b75999464325cb983747082d51274c4ca61458aae3b1dc592e9a6ed"}, {"bytes": 54639557, "date": "2026-08-21", "kind": "daily_replays", "name": "replays_2026-08-21.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-21.parquet", "sha256": "cc9a5655263691f63ff4a6d4e93ced8d5fe033e959f8f8aafd999fb369caef18"}, {"bytes": 48089441, "date": "2026-08-20", "kind": "daily_replays", "name": "replays_2026-08-20.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-20.parquet", "sha256": "62cff77ab4d41d515422a2546ac08c8a571d4882fb7cb8253d0e1712c1e7c380"}, {"bytes": 53373427, "date": "2026-08-19", "kind": "daily_replays", "name": "replays_2026-08-19.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-19.parquet", "sha256": "11ae4a8eede12d7f658d0c1e6fcbe9b697890cc42206da9280e145199877f3fc"}, {"bytes": 42928204, "date": "2026-08-18", "kind": "daily_replays", "name": "replays_2026-08-18.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-18.parquet", "sha256": "0aedf432034c7b21d4533e70d5ec6bfa92e6fccbdaa567818e57df501b1dee76"}, {"bytes": 62522096, "date": "2026-08-17", "kind": "daily_replays", "name": "replays_2026-08-17.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-17.parquet", "sha256": "09d5a11f1845779c179c8bd743d6d66283c1dc5f866f477a5d43e9616332f800"}, {"bytes": 61483789, "date": "2026-08-16", "kind": "daily_replays", "name": "replays_2026-08-16.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-16.parquet", "sha256": "f5ff68c2f33cac5725221cc6e077e12ef0547e31606785403c0e70d9e8071d68"}, {"bytes": 67393391, "date": "2026-08-15", "kind": "daily_replays", "name": "replays_2026-08-15.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-15.parquet", "sha256": "674bde527eb943d0c86d1613b35ba3a690435d3574119c11d4a4df87bd1a62a5"}, {"bytes": 47969571, "date": "2026-08-14", "kind": "daily_replays", "name": "replays_2026-08-14.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-14.parquet", "sha256": "95e5bd27a2c54641a2d421d21640ddecd14357875a45f490b627b2bf89fdb42b"}, {"bytes": 42042053, "date": "2026-08-13", "kind": "daily_replays", "name": "replays_2026-08-13.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-13.parquet", "sha256": "de76938d8b4e19d07ae5484b29adcbef3753bf9a60412f60ca6749d784ea97af"}, {"bytes": 45792559, "date": "2026-08-12", "kind": "daily_replays", "name": "replays_2026-08-12.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-12.parquet", "sha256": "930b93833f1dcc186ad0299c6018ad2773d7077c73b21159f71e50d671648018"}, {"bytes": 45321223, "date": "2026-08-11", "kind": "daily_replays", "name": "replays_2026-08-11.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-11.parquet", "sha256": "e9d8a375be2d4dbf85b2e44f3f3415f3f62177e1616af68be985d3200df3304c"}, {"bytes": 42987550, "date": "2026-08-10", "kind": "daily_replays", "name": "replays_2026-08-10.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-10.parquet", "sha256": "74fda300d12c457649510c83c01617d814677875cd6776402fe462558bfdfcf6"}, {"bytes": 47538613, "date": "2026-08-09", "kind": "daily_replays", "name": "replays_2026-08-09.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-09.parquet", "sha256": "85797b2ef1baa35cdafde037c619aba79d6d81ff3290f0dc0ea9053f782d9624"}, {"bytes": 34893948, "date": "2026-08-08", "kind": "daily_replays", "name": "replays_2026-08-08.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-08.parquet", "sha256": "559c3f82f7a0967079b0e69e0dd07ff3e44ddcaf34f54ed219f7b1c7e692011a"}, {"bytes": 34200270, "date": "2026-08-07", "kind": "daily_replays", "name": "replays_2026-08-07.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-07.parquet", "sha256": "528f647a5aff18b0a7edab5da507d55721542622ed8d5065b0ffc47f94706545"}, {"bytes": 36694501, "date": "2026-08-06", "kind": "daily_replays", "name": "replays_2026-08-06.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-06.parquet", "sha256": "986cea6e85d1bbd1bd028943bd1028853b663ff784ffcecec9b3418fcf77906b"}, {"bytes": 35651661, "date": "2026-08-05", "kind": "daily_replays", "name": "replays_2026-08-05.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-05.parquet", "sha256": "5829f452c7c8530ffdaa06a36aa223d4f3961731062df4dbaeab7866b1509a44"}, {"bytes": 31401967, "date": "2026-08-04", "kind": "daily_replays", "name": "replays_2026-08-04.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-04.parquet", "sha256": "f608b60897132074dd6dc70e6fa6cf01497e43f824c6850f869255c291d5bb48"}, {"bytes": 28647980, "date": "2026-08-03", "kind": "daily_replays", "name": "replays_2026-08-03.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-03.parquet", "sha256": "9a9be60d8d06e12b68c8af5571bf9f1972e2a47765378910093ef73f53d6bb0b"}, {"bytes": 46858722, "date": "2026-08-02", "kind": "daily_replays", "name": "replays_2026-08-02.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-02.parquet", "sha256": "ad88f35194e005e180faaaf67dddb1fabb0489cf69e5386ad696de0ef9af14b3"}, {"bytes": 50965371, "date": "2026-08-01", "kind": "daily_replays", "name": "replays_2026-08-01.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-08-01.parquet", "sha256": "5724d20ec7f07974d94d9092fd32601fcc5c3fbc0c124ca698e93533fc4bc2aa"}, {"bytes": 56053811, "date": "2026-07-31", "kind": "daily_replays", "name": "replays_2026-07-31.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-07-31.parquet", "sha256": "f58ae9ffeff04e97964b83a674e190799ddf6faec6f357d274e95cf837ad2daf"}, {"bytes": 29352170, "date": "2026-07-30", "kind": "daily_replays", "name": "replays_2026-07-30.parquet", "s3_key": "external/frontier_replays/v1/top10_archive/raw/replays_2026-07-30.parquet", "sha256": "18d36fffebc682741f76eb878a16e4e2e7435e21c71fcb540516f22ea4eac428"}]}, "data": {}, "deployed_policy_changed": false, "elapsed_seconds": 74.379, "episode_feedback_status": "COMPLETE_SELECTED_SAMPLE", "episode_selection": {"complete_history_verified": false, "eligible_in_returned_listing": 10, "ignored": [{"id": "112111032", "reason": "not_completed_public_episode", "state": "COMPLETE", "type": "EPISODE_TYPE_VALIDATION"}], "selected": [{"createTime": "2026-09-22T18:05:56.631000", "endTime": "2026-09-22T18:10:09.022000", "id": "112112297", "state": "EpisodeState.COMPLETED", "type": "EpisodeType.EPISODE_TYPE_PUBLIC"}, {"createTime": "2026-09-22T18:09:56.082000", "endTime": "2026-09-22T18:12:09.521000", "id": "112113452", "state": "EpisodeState.COMPLETED", "type": "EpisodeType.EPISODE_TYPE_PUBLIC"}, {"createTime": "2026-09-22T18:13:59.146000", "endTime": "2026-09-22T18:18:30.060000", "id": "112114637", "state": "EpisodeState.COMPLETED", "type": "EpisodeType.EPISODE_TYPE_PUBLIC"}, {"createTime": "2026-09-22T18:17:57.454000", "endTime": "2026-09-22T18:21:53.962000", "id": "112115754", "state": "EpisodeState.COMPLETED", "type": "EpisodeType.EPISODE_TYPE_PUBLIC"}, {"createTime": "2026-09-22T18:34:29.892000", "endTime": "2026-09-22T18:39:10.913000", "id": "112119192", "state": "EpisodeState.COMPLETED", "type": "EpisodeType.EPISODE_TYPE_PUBLIC"}, {"createTime": "2026-09-22T18:38:32.007000", "endTime": "2026-09-22T18:41:58.934000", "id": "112120315", "state": "EpisodeState.COMPLETED", "type": "EpisodeType.EPISODE_TYPE_PUBLIC"}, {"createTime": "2026-09-22T18:42:29.663000", "endTime": "2026-09-22T18:47:52.573000", "id": "112121431", "state": "EpisodeState.COMPLETED", "type": "EpisodeType.EPISODE_TYPE_PUBLIC"}, {"createTime": "2026-09-22T18:46:27.999000", "endTime": "2026-09-22T18:49:47.489000", "id": "112122469", "state": "EpisodeState.COMPLETED", "type": "EpisodeType.EPISODE_TYPE_PUBLIC"}], "selection": "earliest four and latest four, selected only by time", "submission_ref": "56471163"}, "github_write_performed": false, "local_diagnostics": {"cash_margin_mean": 1302.015625, "direct_games": 64, "direct_losses": 14, "direct_seed_clusters": 32, "direct_seed_results": [{"margin": 2574.0, "score": 1.0, "seed": 1609224801}, {"margin": 1516.0, "score": 1.0, "seed": 1609224802}, {"margin": 2042.0, "score": 1.0, "seed": 1609224803}, {"margin": 981.0, "score": 1.0, "seed": 1609224804}, {"margin": -42.0, "score": 0.0, "seed": 1609224805}, {"margin": 780.0, "score": 1.0, "seed": 1609224806}, {"margin": 6392.0, "score": 1.0, "seed": 1609224807}, {"margin": -1097.0, "score": 0.0, "seed": 1609224808}, {"margin": 1151.0, "score": 1.0, "seed": 1609224809}, {"margin": 294.0, "score": 1.0, "seed": 1609224810}, {"margin": -1984.0, "score": 0.0, "seed": 1609224811}, {"margin": 1419.0, "score": 1.0, "seed": 1609224812}, {"margin": 801.0, "score": 1.0, "seed": 1609224813}, {"margin": -162.0, "score": 0.0, "seed": 1609224814}, {"margin": 816.0, "score": 1.0, "seed": 1609224815}, {"margin": -1894.0, "score": 0.0, "seed": 1609224816}, {"margin": 1045.0, "score": 1.0, "seed": 1609224817}, {"margin": 822.0, "score": 1.0, "seed": 1609224818}, {"margin": 798.0, "score": 1.0, "seed": 1609224819}, {"margin": 7863.0, "score": 1.0, "seed": 1609224820}, {"margin": 2137.0, "score": 1.0, "seed": 1609224821}, {"margin": -1768.0, "score": 0.0, "seed": 1609224822}, {"margin": 4062.5, "score": 1.0, "seed": 1609224823}, {"margin": 735.0, "score": 1.0, "seed": 1609224824}, {"margin": 450.0, "score": 1.0, "seed": 1609224825}, {"margin": 128.0, "score": 1.0, "seed": 1609224826}, {"margin": 941.0, "score": 1.0, "seed": 1609224827}, {"margin": 1456.0, "score": 1.0, "seed": 1609224828}, {"margin": -247.0, "score": 0.0, "seed": 1609224829}, {"margin": 6843.0, "score": 1.0, "seed": 1609224830}, {"margin": 1476.0, "score": 1.0, "seed": 1609224831}, {"margin": 1336.0, "score": 1.0, "seed": 1609224832}], "direct_wins": 50, "field": {"sale_timing": {"games": 192, "losses": 146, "wins": 46}, "timing_current": {"games": 192, "losses": 26, "wins": 166}}, "interpretation": "Post-confirmation descriptive failure analysis. Realized shops are outcomes of interactive trajectories, not exogenous strata. No causal attribution or new validation claim.", "losing_seed_clusters": 7, "losses": [{"cash_margin": -42.0, "daily_margin": [{"margin": -16.0, "step": 24}, {"margin": 13.0, "step": 48}, {"margin": 13.0, "step": 72}, {"margin": 73.0, "step": 96}, {"margin": 74.0, "step": 120}, {"margin": 74.0, "step": 144}, {"margin": 74.0, "step": 168}, {"margin": 74.0, "step": 192}, {"margin": 144.0, "step": 216}, {"margin": 218.0, "step": 240}, {"margin": 177.0, "step": 264}, {"margin": 551.0, "step": 288}, {"margin": 835.0, "step": 312}, {"margin": -4.0, "step": 336}, {"margin": -22.0, "step": 360}, {"margin": -26.0, "step": 384}, {"margin": -26.0, "step": 408}, {"margin": 29.0, "step": 432}, {"margin": 70.0, "step": 456}, {"margin": 197.0, "step": 480}, {"margin": 239.0, "step": 504}, {"margin": 189.0, "step": 528}, {"margin": 60.0, "step": 552}, {"margin": 223.0, "step": 576}, {"margin": 132.0, "step": 600}, {"margin": 249.0, "step": 624}, {"margin": -156.0, "step": 648}, {"margin": -40.0, "step": 672}, {"margin": -42.0, "step": 696}, {"margin": -42.0, "step": 719}], "realized_shops": ["BAKERY", "SMOOTHIE_SHOP", "FARMERS_MARKET", "PET_CAFE", "BRUNCH_SPOT", "BRUNCH_SPOT", "BRUNCH_SPOT", "BRUNCH_SPOT"], "seat": 0, "seed": 1609224805}, {"cash_margin": -42.0, "daily_margin": [{"margin": -16.0, "step": 24}, {"margin": 13.0, "step": 48}, {"margin": 13.0, "step": 72}, {"margin": 73.0, "step": 96}, {"margin": 74.0, "step": 120}, {"margin": 74.0, "step": 144}, {"margin": 74.0, "step": 168}, {"margin": 74.0, "step": 192}, {"margin": 144.0, "step": 216}, {"margin": 218.0, "step": 240}, {"margin": 177.0, "step": 264}, {"margin": 551.0, "step": 288}, {"margin": 835.0, "step": 312}, {"margin": -4.0, "step": 336}, {"margin": -22.0, "step": 360}, {"margin": -26.0, "step": 384}, {"margin": -26.0, "step": 408}, {"margin": 29.0, "step": 432}, {"margin": 70.0, "step": 456}, {"margin": 197.0, "step": 480}, {"margin": 239.0, "step": 504}, {"margin": 189.0, "step": 528}, {"margin": 60.0, "step": 552}, {"margin": 223.0, "step": 576}, {"margin": 132.0, "step": 600}, {"margin": 249.0, "step": 624}, {"margin": -156.0, "step": 648}, {"margin": -40.0, "step": 672}, {"margin": -42.0, "step": 696}, {"margin": -42.0, "step": 719}], "realized_shops": ["BAKERY", "SMOOTHIE_SHOP", "FARMERS_MARKET", "PET_CAFE", "BRUNCH_SPOT", "BRUNCH_SPOT", "BRUNCH_SPOT", "BRUNCH_SPOT"], "seat": 1, "seed": 1609224805}, {"cash_margin": -1097.0, "daily_margin": [{"margin": -16.0, "step": 24}, {"margin": 13.0, "step": 48}, {"margin": 13.0, "step": 72}, {"margin": 73.0, "step": 96}, {"margin": 74.0, "step": 120}, {"margin": 74.0, "step": 144}, {"margin": 87.0, "step": 168}, {"margin": 87.0, "step": 192}, {"margin": 159.0, "step": 216}, {"margin": 235.0, "step": 240}, {"margin": 356.0, "step": 264}, {"margin": 765.0, "step": 288}, {"margin": 1021.0, "step": 312}, {"margin": 1003.0, "step": 336}, {"margin": 615.0, "step": 360}, {"margin": 126.0, "step": 384}, {"margin": -366.0, "step": 408}, {"margin": -412.0, "step": 432}, {"margin": -454.0, "step": 456}, {"margin": -294.0, "step": 480}, {"margin": -481.0, "step": 504}, {"margin": -967.0, "step": 528}, {"margin": -1333.0, "step": 552}, {"margin": -1190.0, "step": 576}, {"margin": -1368.0, "step": 600}, {"margin": -1507.0, "step": 624}, {"margin": -1346.0, "step": 648}, {"margin": -1302.0, "step": 672}, {"margin": -1098.0, "step": 696}, {"margin": -1097.0, "step": 719}], "realized_shops": ["BAKERY", "BRUNCH_SPOT", "BRUNCH_SPOT", "BAKERY", "PET_CAFE", "FARMERS_MARKET", "YARN_STORE", "BAKERY"], "seat": 0, "seed": 1609224808}, {"cash_margin": -1097.0, "daily_margin": [{"margin": -16.0, "step": 24}, {"margin": 13.0, "step": 48}, {"margin": 13.0, "step": 72}, {"margin": 73.0, "step": 96}, {"margin": 74.0, "step": 120}, {"margin": 74.0, "step": 144}, {"margin": 87.0, "step": 168}, {"margin": 87.0, "step": 192}, {"margin": 159.0, "step": 216}, {"margin": 235.0, "step": 240}, {"margin": 356.0, "step": 264}, {"margin": 765.0, "step": 288}, {"margin": 1021.0, "step": 312}, {"margin": 1003.0, "step": 336}, {"margin": 615.0, "step": 360}, {"margin": 126.0, "step": 384}, {"margin": -366.0, "step": 408}, {"margin": -412.0, "step": 432}, {"margin": -454.0, "step": 456}, {"margin": -294.0, "step": 480}, {"margin": -481.0, "step": 504}, {"margin": -967.0, "step": 528}, {"margin": -1333.0, "step": 552}, {"margin": -1190.0, "step": 576}, {"margin": -1368.0, "step": 600}, {"margin": -1507.0, "step": 624}, {"margin": -1346.0, "step": 648}, {"margin": -1302.0, "step": 672}, {"margin": -1098.0, "step": 696}, {"margin": -1097.0, "step": 719}], "realized_shops": ["BAKERY", "BRUNCH_SPOT", "BRUNCH_SPOT", "BAKERY", "PET_CAFE", "FARMERS_MARKET", "YARN_STORE", "BAKERY"], "seat": 1, "seed": 1609224808}, {"cash_margin": -1984.0, "daily_margin": [{"margin": -16.0, "step": 24}, {"margin": 13.0, "step": 48}, {"margin": 13.0, "step": 72}, {"margin": 72.0, "step": 96}, {"margin": 74.0, "step": 120}, {"margin": 75.0, "step": 144}, {"margin": 74.0, "step": 168}, {"margin": 74.0, "step": 192}, {"margin": 142.0, "step": 216}, {"margin": 214.0, "step": 240}, {"margin": 174.0, "step": 264}, {"margin": 533.0, "step": 288}, {"margin": 813.0, "step": 312}, {"margin": 5.0, "step": 336}, {"margin": -7.0, "step": 360}, {"margin": -11.0, "step": 384}, {"margin": -222.0, "step": 408}, {"margin": -267.0, "step": 432}, {"margin": -713.0, "step": 456}, {"margin": -1126.0, "step": 480}, {"margin": -1163.0, "step": 504}, {"margin": -1459.0, "step": 528}, {"margin": -1487.0, "step": 552}, {"margin": -1621.0, "step": 576}, {"margin": -1171.0, "step": 600}, {"margin": -1708.0, "step": 624}, {"margin": -2063.0, "step": 648}, {"margin": -1865.0, "step": 672}, {"margin": -1900.0, "step": 696}, {"margin": -1984.0, "step": 719}], "realized_shops": ["PET_CAFE", "ICE_CREAM_SHOP", "YARN_STORE", "FARMERS_MARKET", "BAKERY", "BAKERY", "ICE_CREAM_SHOP", "FARMERS_MARKET"], "seat": 0, "seed": 1609224811}, {"cash_margin": -1984.0, "daily_margin": [{"margin": -16.0, "step": 24}, {"margin": 13.0, "step": 48}, {"margin": 13.0, "step": 72}, {"margin": 72.0, "step": 96}, {"margin": 74.0, "step": 120}, {"margin": 75.0, "step": 144}, {"margin": 74.0, "step": 168}, {"margin": 74.0, "step": 192}, {"margin": 142.0, "step": 216}, {"margin": 214.0, "step": 240}, {"margin": 174.0, "step": 264}, {"margin": 533.0, "step": 288}, {"margin": 813.0, "step": 312}, {"margin": 5.0, "step": 336}, {"margin": -7.0, "step": 360}, {"margin": -11.0, "step": 384}, {"margin": -222.0, "step": 408}, {"margin": -267.0, "step": 432}, {"margin": -713.0, "step": 456}, {"margin": -1126.0, "step": 480}, {"margin": -1163.0, "step": 504}, {"margin": -1459.0, "step": 528}, {"margin": -1487.0, "step": 552}, {"margin": -1621.0, "step": 576}, {"margin": -1171.0, "step": 600}, {"margin": -1708.0, "step": 624}, {"margin": -2063.0, "step": 648}, {"margin": -1865.0, "step": 672}, {"margin": -1900.0, "step": 696}, {"margin": -1984.0, "step": 719}], "realized_shops": ["PET_CAFE", "ICE_CREAM_SHOP", "YARN_STORE", "FARMERS_MARKET", "BAKERY", "BAKERY", "ICE_CREAM_SHOP", "FARMERS_MARKET"], "seat": 1, "seed": 1609224811}, {"cash_margin": -162.0, "daily_margin": [{"margin": -16.0, "step": 24}, {"margin": 13.0, "step": 48}, {"margin": 13.0, "step": 72}, {"margin": 72.0, "step": 96}, {"margin": 74.0, "step": 120}, {"margin": 75.0, "step": 144}, {"margin": -298.0, "step": 168}, {"margin": 78.0, "step": 192}, {"margin": 146.0, "step": 216}, {"margin": 218.0, "step": 240}, {"margin": 177.0, "step": 264}, {"margin": 1015.0, "step": 288}, {"margin": 1307.0, "step": 312}, {"margin": 762.0, "step": 336}, {"margin": 405.0, "step": 360}, {"margin": 442.0, "step": 384}, {"margin": 444.0, "step": 408}, {"margin": 562.0, "step": 432}, {"margin": 733.0, "step": 456}, {"margin": 675.0, "step": 480}, {"margin": 811.0, "step": 504}, {"margin": 723.0, "step": 528}, {"margin": 504.0, "step": 552}, {"margin": 622.0, "step": 576}, {"margin": 612.0, "step": 600}, {"margin": 580.0, "step": 624}, {"margin": 294.0, "step": 648}, {"margin": 387.0, "step": 672}, {"margin": 225.0, "step": 696}, {"margin": -162.0, "step": 719}], "realized_shops": ["PET_CAFE", "FARMERS_MARKET", "BAKERY", "BRUNCH_SPOT", "BAKERY", "PET_CAFE", "PET_CAFE", "SMOOTHIE_SHOP"], "seat": 1, "seed": 1609224814}, {"cash_margin": -1894.0, "daily_margin": [{"margin": -16.0, "step": 24}, {"margin": 13.0, "step": 48}, {"margin": 13.0, "step": 72}, {"margin": 73.0, "step": 96}, {"margin": 74.0, "step": 120}, {"margin": 74.0, "step": 144}, {"margin": 87.0, "step": 168}, {"margin": 87.0, "step": 192}, {"margin": 159.0, "step": 216}, {"margin": 236.0, "step": 240}, {"margin": 358.0, "step": 264}, {"margin": 741.0, "step": 288}, {"margin": 998.0, "step": 312}, {"margin": 989.0, "step": 336}, {"margin": 487.0, "step": 360}, {"margin": 76.0, "step": 384}, {"margin": -271.0, "step": 408}, {"margin": -243.0, "step": 432}, {"margin": -375.0, "step": 456}, {"margin": -456.0, "step": 480}, {"margin": -410.0, "step": 504}, {"margin": -679.0, "step": 528}, {"margin": -1494.0, "step": 552}, {"margin": -1490.0, "step": 576}, {"margin": -1038.0, "step": 600}, {"margin": -1297.0, "step": 624}, {"margin": -1496.0, "step": 648}, {"margin": -1239.0, "step": 672}, {"margin": -1793.0, "step": 696}, {"margin": -1894.0, "step": 719}], "realized_shops": ["BAKERY", "BRUNCH_SPOT", "SMOOTHIE_SHOP", "SMOOTHIE_SHOP", "ICE_CREAM_SHOP", "YARN_STORE", "PIZZA_SHOP", "YARN_STORE"], "seat": 0, "seed": 1609224816}, {"cash_margin": -1894.0, "daily_margin": [{"margin": -16.0, "step": 24}, {"margin": 13.0, "step": 48}, {"margin": 13.0, "step": 72}, {"margin": 73.0, "step": 96}, {"margin": 74.0, "step": 120}, {"margin": 74.0, "step": 144}, {"margin": 87.0, "step": 168}, {"margin": 87.0, "step": 192}, {"margin": 159.0, "step": 216}, {"margin": 236.0, "step": 240}, {"margin": 358.0, "step": 264}, {"margin": 741.0, "step": 288}, {"margin": 998.0, "step": 312}, {"margin": 989.0, "step": 336}, {"margin": 487.0, "step": 360}, {"margin": 76.0, "step": 384}, {"margin": -271.0, "step": 408}, {"margin": -243.0, "step": 432}, {"margin": -375.0, "step": 456}, {"margin": -456.0, "step": 480}, {"margin": -410.0, "step": 504}, {"margin": -679.0, "step": 528}, {"margin": -1494.0, "step": 552}, {"margin": -1490.0, "step": 576}, {"margin": -1038.0, "step": 600}, {"margin": -1297.0, "step": 624}, {"margin": -1496.0, "step": 648}, {"margin": -1239.0, "step": 672}, {"margin": -1793.0, "step": 696}, {"margin": -1894.0, "step": 719}], "realized_shops": ["BAKERY", "BRUNCH_SPOT", "SMOOTHIE_SHOP", "SMOOTHIE_SHOP", "ICE_CREAM_SHOP", "YARN_STORE", "PIZZA_SHOP", "YARN_STORE"], "seat": 1, "seed": 1609224816}, {"cash_margin": -162.0, "daily_margin": [{"margin": -16.0, "step": 24}, {"margin": 13.0, "step": 48}, {"margin": 13.0, "step": 72}, {"margin": 72.0, "step": 96}, {"margin": 74.0, "step": 120}, {"margin": 75.0, "step": 144}, {"margin": -298.0, "step": 168}, {"margin": 78.0, "step": 192}, {"margin": 146.0, "step": 216}, {"margin": 218.0, "step": 240}, {"margin": 177.0, "step": 264}, {"margin": 1015.0, "step": 288}, {"margin": 1307.0, "step": 312}, {"margin": 762.0, "step": 336}, {"margin": 405.0, "step": 360}, {"margin": 442.0, "step": 384}, {"margin": 444.0, "step": 408}, {"margin": 562.0, "step": 432}, {"margin": 733.0, "step": 456}, {"margin": 675.0, "step": 480}, {"margin": 811.0, "step": 504}, {"margin": 723.0, "step": 528}, {"margin": 504.0, "step": 552}, {"margin": 622.0, "step": 576}, {"margin": 612.0, "step": 600}, {"margin": 580.0, "step": 624}, {"margin": 294.0, "step": 648}, {"margin": 387.0, "step": 672}, {"margin": 225.0, "step": 696}, {"margin": -162.0, "step": 719}], "realized_shops": ["PET_CAFE", "FARMERS_MARKET", "BAKERY", "BRUNCH_SPOT", "BAKERY", "PET_CAFE", "PET_CAFE", "SMOOTHIE_SHOP"], "seat": 0, "seed": 1609224814}, {"cash_margin": -1768.0, "daily_margin": [{"margin": -16.0, "step": 24}, {"margin": 13.0, "step": 48}, {"margin": 13.0, "step": 72}, {"margin": 72.0, "step": 96}, {"margin": 74.0, "step": 120}, {"margin": 75.0, "step": 144}, {"margin": 74.0, "step": 168}, {"margin": 74.0, "step": 192}, {"margin": 142.0, "step": 216}, {"margin": 214.0, "step": 240}, {"margin": 174.0, "step": 264}, {"margin": 533.0, "step": 288}, {"margin": 889.0, "step": 312}, {"margin": 81.0, "step": 336}, {"margin": 68.0, "step": 360}, {"margin": 64.0, "step": 384}, {"margin": -161.0, "step": 408}, {"margin": -75.0, "step": 432}, {"margin": -369.0, "step": 456}, {"margin": -783.0, "step": 480}, {"margin": -1052.0, "step": 504}, {"margin": -1329.0, "step": 528}, {"margin": -865.0, "step": 552}, {"margin": -864.0, "step": 576}, {"margin": -669.0, "step": 600}, {"margin": -1008.0, "step": 624}, {"margin": -1104.0, "step": 648}, {"margin": -1156.0, "step": 672}, {"margin": -1735.0, "step": 696}, {"margin": -1768.0, "step": 719}], "realized_shops": ["SMOOTHIE_SHOP", "PIZZA_SHOP", "YARN_STORE", "BAKERY", "FARMERS_MARKET", "ICE_CREAM_SHOP", "ICE_CREAM_SHOP", "SMOOTHIE_SHOP"], "seat": 0, "seed": 1609224822}, {"cash_margin": -1768.0, "daily_margin": [{"margin": -16.0, "step": 24}, {"margin": 13.0, "step": 48}, {"margin": 13.0, "step": 72}, {"margin": 72.0, "step": 96}, {"margin": 74.0, "step": 120}, {"margin": 75.0, "step": 144}, {"margin": 74.0, "step": 168}, {"margin": 74.0, "step": 192}, {"margin": 142.0, "step": 216}, {"margin": 214.0, "step": 240}, {"margin": 174.0, "step": 264}, {"margin": 533.0, "step": 288}, {"margin": 889.0, "step": 312}, {"margin": 81.0, "step": 336}, {"margin": 68.0, "step": 360}, {"margin": 64.0, "step": 384}, {"margin": -161.0, "step": 408}, {"margin": -75.0, "step": 432}, {"margin": -369.0, "step": 456}, {"margin": -783.0, "step": 480}, {"margin": -1052.0, "step": 504}, {"margin": -1329.0, "step": 528}, {"margin": -865.0, "step": 552}, {"margin": -864.0, "step": 576}, {"margin": -669.0, "step": 600}, {"margin": -1008.0, "step": 624}, {"margin": -1104.0, "step": 648}, {"margin": -1156.0, "step": 672}, {"margin": -1735.0, "step": 696}, {"margin": -1768.0, "step": 719}], "realized_shops": ["SMOOTHIE_SHOP", "PIZZA_SHOP", "YARN_STORE", "BAKERY", "FARMERS_MARKET", "ICE_CREAM_SHOP", "ICE_CREAM_SHOP", "SMOOTHIE_SHOP"], "seat": 1, "seed": 1609224822}, {"cash_margin": -247.0, "daily_margin": [{"margin": -16.0, "step": 24}, {"margin": 13.0, "step": 48}, {"margin": 13.0, "step": 72}, {"margin": 72.0, "step": 96}, {"margin": 74.0, "step": 120}, {"margin": 75.0, "step": 144}, {"margin": 74.0, "step": 168}, {"margin": 74.0, "step": 192}, {"margin": 142.0, "step": 216}, {"margin": 214.0, "step": 240}, {"margin": 174.0, "step": 264}, {"margin": 535.0, "step": 288}, {"margin": 902.0, "step": 312}, {"margin": 73.0, "step": 336}, {"margin": 55.0, "step": 360}, {"margin": -149.0, "step": 384}, {"margin": -427.0, "step": 408}, {"margin": -188.0, "step": 432}, {"margin": -408.0, "step": 456}, {"margin": 18.0, "step": 480}, {"margin": -57.0, "step": 504}, {"margin": -12.0, "step": 528}, {"margin": -60.0, "step": 552}, {"margin": 605.0, "step": 576}, {"margin": 417.0, "step": 600}, {"margin": 413.0, "step": 624}, {"margin": -307.0, "step": 648}, {"margin": -256.0, "step": 672}, {"margin": -248.0, "step": 696}, {"margin": -247.0, "step": 719}], "realized_shops": ["SMOOTHIE_SHOP", "PIZZA_SHOP", "FARMERS_MARKET", "PIZZA_SHOP", "YARN_STORE", "PIZZA_SHOP", "SMOOTHIE_SHOP", "FARMERS_MARKET"], "seat": 0, "seed": 1609224829}, {"cash_margin": -247.0, "daily_margin": [{"margin": -16.0, "step": 24}, {"margin": 13.0, "step": 48}, {"margin": 13.0, "step": 72}, {"margin": 72.0, "step": 96}, {"margin": 74.0, "step": 120}, {"margin": 75.0, "step": 144}, {"margin": 74.0, "step": 168}, {"margin": 74.0, "step": 192}, {"margin": 142.0, "step": 216}, {"margin": 214.0, "step": 240}, {"margin": 174.0, "step": 264}, {"margin": 535.0, "step": 288}, {"margin": 902.0, "step": 312}, {"margin": 73.0, "step": 336}, {"margin": 55.0, "step": 360}, {"margin": -149.0, "step": 384}, {"margin": -427.0, "step": 408}, {"margin": -188.0, "step": 432}, {"margin": -408.0, "step": 456}, {"margin": 18.0, "step": 480}, {"margin": -57.0, "step": 504}, {"margin": -12.0, "step": 528}, {"margin": -60.0, "step": 552}, {"margin": 605.0, "step": 576}, {"margin": 417.0, "step": 600}, {"margin": 413.0, "step": 624}, {"margin": -307.0, "step": 648}, {"margin": -256.0, "step": 672}, {"margin": -248.0, "step": 696}, {"margin": -247.0, "step": 719}], "realized_shops": ["SMOOTHIE_SHOP", "PIZZA_SHOP", "FARMERS_MARKET", "PIZZA_SHOP", "YARN_STORE", "PIZZA_SHOP", "SMOOTHIE_SHOP", "FARMERS_MARKET"], "seat": 1, "seed": 1609224829}], "new_fits": 0, "new_games": 0, "selection_or_validation_reused_as_new_evidence": false}, "max_broad_metadata_bytes": 268435456, "max_new_compact_payload_bytes": 1073741824, "max_new_compact_shards": 32, "max_public_replays": 8, "max_runtime_seconds": 900, "max_total_new_payload_bytes": 2147483648, "memory_limit_gib": 4, "milestone": "verified_submission_and_incremental_feedback_v1", "new_compute_provisioned": false, "new_fits": 0, "new_payload_bytes": 524083369, "next_research": "Diagnose completed online losses and retained local losses; freeze one mechanistic intervention, then test on unused seeds. Do not tune on confirmation seeds and call that new confirmation.", "per_shard_bytes": 201326592, "prior_confirmation_games_preserved": 452, "prior_games_replayed": 0, "prior_nomination_games_preserved": 100, "python": "3.12.14 (main, Sep  2 2026, 23:27:36) [GCC 15.3.0]", "python_executable": "/opt/conda/bin/python", "raw_replays": [{"bytes": 30062753, "episode_id": "112112297", "s3_key": "external/frontier_replays/v1/derived/live_feedback_delta_v1/replays/56471163/112112297/b6ff3276e35ed8be6369ea3e2e36babcac7d840d9851c813ecce133b0990da20/episode-112112297-replay.json", "sha256": "b6ff3276e35ed8be6369ea3e2e36babcac7d840d9851c813ecce133b0990da20"}, {"bytes": 28615649, "episode_id": "112113452", "s3_key": "external/frontier_replays/v1/derived/live_feedback_delta_v1/replays/56471163/112113452/fbb6eab1fa30aba12a16d34b32c1062613df07ede1ce6a1dc8c6d4fdb433b22e/episode-112113452-replay.json", "sha256": "fbb6eab1fa30aba12a16d34b32c1062613df07ede1ce6a1dc8c6d4fdb433b22e"}, {"bytes": 32246753, "episode_id": "112114637", "s3_key": "external/frontier_replays/v1/derived/live_feedback_delta_v1/replays/56471163/112114637/f1b3a4bae545f110f28772938d593d9c6e6c73f6cd022f62d1fa8f8b7fcd4171/episode-112114637-replay.json", "sha256": "f1b3a4bae545f110f28772938d593d9c6e6c73f6cd022f62d1fa8f8b7fcd4171"}, {"bytes": 29968222, "episode_id": "112115754", "s3_key": "external/frontier_replays/v1/derived/live_feedback_delta_v1/replays/56471163/112115754/ef4212733b42d0f80e8e0f52a53e2a89bcb8f126665efb0091a02a22bfef8a8d/episode-112115754-replay.json", "sha256": "ef4212733b42d0f80e8e0f52a53e2a89bcb8f126665efb0091a02a22bfef8a8d"}, {"bytes": 32208566, "episode_id": "112119192", "s3_key": "external/frontier_replays/v1/derived/live_feedback_delta_v1/replays/56471163/112119192/d9277368d60b8900e46aaa5a213f70f23f20ae0d0bb6bd01a6ad94968e084225/episode-112119192-replay.json", "sha256": "d9277368d60b8900e46aaa5a213f70f23f20ae0d0bb6bd01a6ad94968e084225"}, {"bytes": 33589567, "episode_id": "112120315", "s3_key": "external/frontier_replays/v1/derived/live_feedback_delta_v1/replays/56471163/112120315/3ee703f29c547ab37500007c1af69d1c5403d78f73abe029b663731923404557/episode-112120315-replay.json", "sha256": "3ee703f29c547ab37500007c1af69d1c5403d78f73abe029b663731923404557"}, {"bytes": 32725622, "episode_id": "112121431", "s3_key": "external/frontier_replays/v1/derived/live_feedback_delta_v1/replays/56471163/112121431/eb45448cf1c53c3cd4d8c1a1db48aa7ae0cbce9bd09e4f72e40c159411cc22c0/episode-112121431-replay.json", "sha256": "eb45448cf1c53c3cd4d8c1a1db48aa7ae0cbce9bd09e4f72e40c159411cc22c0"}, {"bytes": 33126761, "episode_id": "112122469", "s3_key": "external/frontier_replays/v1/derived/live_feedback_delta_v1/replays/56471163/112122469/e83af6d622556ec28ba5783935e000523dc46f1ca57dacf3fd973e580bf53c2b/episode-112122469-replay.json", "sha256": "e83af6d622556ec28ba5783935e000523dc46f1ca57dacf3fd973e580bf53c2b"}], "release": null, "replays": [{"cash_margin": 57686.0, "daily": [{"animals": 0, "cash_margin": 0.0, "crops": 0, "episode_id": "112112297", "opponent_cash": 3000.0, "opponent_workers": 0, "own_cash": 3000.0, "own_workers": 0, "ready_yield_units": 0, "step": 0}, {"animals": 4, "cash_margin": -28.0, "crops": 20, "episode_id": "112112297", "opponent_cash": 43.0, "opponent_workers": 0, "own_cash": 15.0, "own_workers": 0, "ready_yield_units": 20, "step": 24}, {"animals": 4, "cash_margin": -41.0, "crops": 20, "episode_id": "112112297", "opponent_cash": 137.0, "opponent_workers": 0, "own_cash": 96.0, "own_workers": 0, "ready_yield_units": 20, "step": 48}, {"animals": 5, "cash_margin": 0.0, "crops": 20, "episode_id": "112112297", "opponent_cash": 212.0, "opponent_workers": 0, "own_cash": 212.0, "own_workers": 0, "ready_yield_units": 25, "step": 72}, {"animals": 6, "cash_margin": -425.0, "crops": 19, "episode_id": "112112297", "opponent_cash": 786.0, "opponent_workers": 0, "own_cash": 361.0, "own_workers": 0, "ready_yield_units": 19, "step": 96}, {"animals": 6, "cash_margin": 153.0, "crops": 19, "episode_id": "112112297", "opponent_cash": 613.0, "opponent_workers": 0, "own_cash": 766.0, "own_workers": 0, "ready_yield_units": 19, "step": 120}, {"animals": 6, "cash_margin": 266.0, "crops": 19, "episode_id": "112112297", "opponent_cash": 612.0, "opponent_workers": 0, "own_cash": 878.0, "own_workers": 0, "ready_yield_units": 27, "step": 144}, {"animals": 8, "cash_margin": -83.0, "crops": 29, "episode_id": "112112297", "opponent_cash": 1564.0, "opponent_workers": 0, "own_cash": 1481.0, "own_workers": 0, "ready_yield_units": 29, "step": 168}, {"animals": 10, "cash_margin": 12.0, "crops": 37, "episode_id": "112112297", "opponent_cash": 740.0, "opponent_workers": 0, "own_cash": 752.0, "own_workers": 0, "ready_yield_units": 57, "step": 192}, {"animals": 12, "cash_margin": 1087.0, "crops": 37, "episode_id": "112112297", "opponent_cash": 303.0, "opponent_workers": 0, "own_cash": 1390.0, "own_workers": 0, "ready_yield_units": 61, "step": 216}, {"animals": 13, "cash_margin": 2372.0, "crops": 37, "episode_id": "112112297", "opponent_cash": 105.0, "opponent_workers": 0, "own_cash": 2477.0, "own_workers": 0, "ready_yield_units": 84, "step": 240}, {"animals": 16, "cash_margin": 15235.0, "crops": 32, "episode_id": "112112297", "opponent_cash": 1235.0, "opponent_workers": 0, "own_cash": 16470.0, "own_workers": 0, "ready_yield_units": 25, "step": 264}, {"animals": 17, "cash_margin": 12128.0, "crops": 53, "episode_id": "112112297", "opponent_cash": 3892.0, "opponent_workers": 0, "own_cash": 16020.0, "own_workers": 0, "ready_yield_units": 46, "step": 288}, {"animals": 17, "cash_margin": 11230.0, "crops": 57, "episode_id": "112112297", "opponent_cash": 8513.0, "opponent_workers": 0, "own_cash": 19743.0, "own_workers": 0, "ready_yield_units": 43, "step": 312}, {"animals": 17, "cash_margin": 15376.0, "crops": 57, "episode_id": "112112297", "opponent_cash": 5599.0, "opponent_workers": 0, "own_cash": 20975.0, "own_workers": 0, "ready_yield_units": 59, "step": 336}, {"animals": 17, "cash_margin": 12504.0, "crops": 57, "episode_id": "112112297", "opponent_cash": 12061.0, "opponent_workers": 0, "own_cash": 24565.0, "own_workers": 0, "ready_yield_units": 80, "step": 360}, {"animals": 17, "cash_margin": 13231.0, "crops": 57, "episode_id": "112112297", "opponent_cash": 13700.0, "opponent_workers": 0, "own_cash": 26931.0, "own_workers": 0, "ready_yield_units": 89, "step": 384}, {"animals": 17, "cash_margin": 20619.0, "crops": 58, "episode_id": "112112297", "opponent_cash": 14260.0, "opponent_workers": 0, "own_cash": 34879.0, "own_workers": 0, "ready_yield_units": 78, "step": 408}, {"animals": 17, "cash_margin": 23809.0, "crops": 58, "episode_id": "112112297", "opponent_cash": 17512.0, "opponent_workers": 0, "own_cash": 41321.0, "own_workers": 0, "ready_yield_units": 88, "step": 432}, {"animals": 17, "cash_margin": 25012.0, "crops": 58, "episode_id": "112112297", "opponent_cash": 21949.0, "opponent_workers": 0, "own_cash": 46961.0, "own_workers": 0, "ready_yield_units": 78, "step": 456}, {"animals": 17, "cash_margin": 27567.0, "crops": 58, "episode_id": "112112297", "opponent_cash": 22769.0, "opponent_workers": 0, "own_cash": 50336.0, "own_workers": 0, "ready_yield_units": 91, "step": 480}, {"animals": 17, "cash_margin": 28659.0, "crops": 58, "episode_id": "112112297", "opponent_cash": 23752.0, "opponent_workers": 0, "own_cash": 52411.0, "own_workers": 0, "ready_yield_units": 103, "step": 504}, {"animals": 17, "cash_margin": 31145.0, "crops": 56, "episode_id": "112112297", "opponent_cash": 23900.0, "opponent_workers": 0, "own_cash": 55045.0, "own_workers": 0, "ready_yield_units": 97, "step": 528}, {"animals": 17, "cash_margin": 31258.0, "crops": 58, "episode_id": "112112297", "opponent_cash": 26104.0, "opponent_workers": 0, "own_cash": 57362.0, "own_workers": 0, "ready_yield_units": 102, "step": 552}, {"animals": 17, "cash_margin": 32143.0, "crops": 58, "episode_id": "112112297", "opponent_cash": 27690.0, "opponent_workers": 0, "own_cash": 59833.0, "own_workers": 0, "ready_yield_units": 100, "step": 576}, {"animals": 17, "cash_margin": 34336.0, "crops": 58, "episode_id": "112112297", "opponent_cash": 28074.0, "opponent_workers": 0, "own_cash": 62410.0, "own_workers": 0, "ready_yield_units": 121, "step": 600}, {"animals": 17, "cash_margin": 37429.0, "crops": 58, "episode_id": "112112297", "opponent_cash": 28540.0, "opponent_workers": 0, "own_cash": 65969.0, "own_workers": 0, "ready_yield_units": 105, "step": 624}, {"animals": 16, "cash_margin": 39766.0, "crops": 58, "episode_id": "112112297", "opponent_cash": 28753.0, "opponent_workers": 0, "own_cash": 68519.0, "own_workers": 0, "ready_yield_units": 130, "step": 648}, {"animals": 16, "cash_margin": 44545.0, "crops": 39, "episode_id": "112112297", "opponent_cash": 28554.0, "opponent_workers": 0, "own_cash": 73099.0, "own_workers": 0, "ready_yield_units": 71, "step": 672}, {"animals": 16, "cash_margin": 49220.0, "crops": 21, "episode_id": "112112297", "opponent_cash": 28996.0, "opponent_workers": 0, "own_cash": 78216.0, "own_workers": 0, "ready_yield_units": 66, "step": 696}, {"animals": 16, "cash_margin": 56989.0, "crops": 0, "episode_id": "112112297", "opponent_cash": 33826.0, "opponent_workers": 12, "own_cash": 90815.0, "own_workers": 11, "ready_yield_units": 0, "step": 718}], "episode_id": "112112297", "identity_basis": "target_submission_listing_plus_unique_team_name", "interpretation": "Descriptive time-selected public-game sample; not a rating estimate or causal policy test.", "listing_membership_verified": true, "opponent_reward": 34159.0, "outcome": "WIN", "own_reward": 91845.0, "seat": 0, "statuses": ["DONE", "DONE"], "submission_ref": "56471163"}, {"cash_margin": 99618.0, "daily": [{"animals": 0, "cash_margin": 0.0, "crops": 0, "episode_id": "112113452", "opponent_cash": 3000.0, "opponent_workers": 0, "own_cash": 3000.0, "own_workers": 0, "ready_yield_units": 0, "step": 0}, {"animals": 4, "cash_margin": -78.0, "crops": 20, "episode_id": "112113452", "opponent_cash": 93.0, "opponent_workers": 0, "own_cash": 15.0, "own_workers": 0, "ready_yield_units": 20, "step": 24}, {"animals": 4, "cash_margin": -197.0, "crops": 20, "episode_id": "112113452", "opponent_cash": 297.0, "opponent_workers": 0, "own_cash": 100.0, "own_workers": 0, "ready_yield_units": 20, "step": 48}, {"animals": 5, "cash_margin": -453.0, "crops": 20, "episode_id": "112113452", "opponent_cash": 667.0, "opponent_workers": 0, "own_cash": 214.0, "own_workers": 0, "ready_yield_units": 25, "step": 72}, {"animals": 6, "cash_margin": -513.0, "crops": 19, "episode_id": "112113452", "opponent_cash": 875.0, "opponent_workers": 0, "own_cash": 362.0, "own_workers": 0, "ready_yield_units": 19, "step": 96}, {"animals": 6, "cash_margin": -639.0, "crops": 19, "episode_id": "112113452", "opponent_cash": 1409.0, "opponent_workers": 0, "own_cash": 770.0, "own_workers": 0, "ready_yield_units": 19, "step": 120}, {"animals": 6, "cash_margin": -723.0, "crops": 19, "episode_id": "112113452", "opponent_cash": 1607.0, "opponent_workers": 0, "own_cash": 884.0, "own_workers": 0, "ready_yield_units": 27, "step": 144}, {"animals": 8, "cash_margin": -488.0, "crops": 29, "episode_id": "112113452", "opponent_cash": 1786.0, "opponent_workers": 0, "own_cash": 1298.0, "own_workers": 0, "ready_yield_units": 29, "step": 168}, {"animals": 10, "cash_margin": 642.0, "crops": 37, "episode_id": "112113452", "opponent_cash": 90.0, "opponent_workers": 0, "own_cash": 732.0, "own_workers": 0, "ready_yield_units": 57, "step": 192}, {"animals": 12, "cash_margin": -437.0, "crops": 37, "episode_id": "112113452", "opponent_cash": 2447.0, "opponent_workers": 0, "own_cash": 2010.0, "own_workers": 0, "ready_yield_units": 61, "step": 216}, {"animals": 13, "cash_margin": 30.0, "crops": 37, "episode_id": "112113452", "opponent_cash": 3062.0, "opponent_workers": 0, "own_cash": 3092.0, "own_workers": 0, "ready_yield_units": 77, "step": 240}, {"animals": 16, "cash_margin": 17312.0, "crops": 32, "episode_id": "112113452", "opponent_cash": 726.0, "opponent_workers": 0, "own_cash": 18038.0, "own_workers": 0, "ready_yield_units": 19, "step": 264}, {"animals": 17, "cash_margin": 14610.0, "crops": 53, "episode_id": "112113452", "opponent_cash": 3700.0, "opponent_workers": 0, "own_cash": 18310.0, "own_workers": 0, "ready_yield_units": 39, "step": 288}, {"animals": 17, "cash_margin": 17394.0, "crops": 57, "episode_id": "112113452", "opponent_cash": 5677.0, "opponent_workers": 0, "own_cash": 23071.0, "own_workers": 0, "ready_yield_units": 35, "step": 312}, {"animals": 17, "cash_margin": 17814.0, "crops": 57, "episode_id": "112113452", "opponent_cash": 7400.0, "opponent_workers": 0, "own_cash": 25214.0, "own_workers": 0, "ready_yield_units": 67, "step": 336}, {"animals": 17, "cash_margin": 24239.0, "crops": 57, "episode_id": "112113452", "opponent_cash": 7166.0, "opponent_workers": 0, "own_cash": 31405.0, "own_workers": 0, "ready_yield_units": 77, "step": 360}, {"animals": 17, "cash_margin": 26174.0, "crops": 57, "episode_id": "112113452", "opponent_cash": 11482.0, "opponent_workers": 0, "own_cash": 37656.0, "own_workers": 0, "ready_yield_units": 90, "step": 384}, {"animals": 17, "cash_margin": 36734.0, "crops": 58, "episode_id": "112113452", "opponent_cash": 11793.0, "opponent_workers": 0, "own_cash": 48527.0, "own_workers": 0, "ready_yield_units": 77, "step": 408}, {"animals": 17, "cash_margin": 45948.0, "crops": 58, "episode_id": "112113452", "opponent_cash": 12600.0, "opponent_workers": 0, "own_cash": 58548.0, "own_workers": 0, "ready_yield_units": 89, "step": 432}, {"animals": 17, "cash_margin": 51204.0, "crops": 58, "episode_id": "112113452", "opponent_cash": 15480.0, "opponent_workers": 0, "own_cash": 66684.0, "own_workers": 0, "ready_yield_units": 77, "step": 456}, {"animals": 17, "cash_margin": 57164.0, "crops": 58, "episode_id": "112113452", "opponent_cash": 18968.0, "opponent_workers": 0, "own_cash": 76132.0, "own_workers": 0, "ready_yield_units": 94, "step": 480}, {"animals": 17, "cash_margin": 61194.0, "crops": 58, "episode_id": "112113452", "opponent_cash": 25959.0, "opponent_workers": 0, "own_cash": 87153.0, "own_workers": 0, "ready_yield_units": 111, "step": 504}, {"animals": 17, "cash_margin": 65792.0, "crops": 57, "episode_id": "112113452", "opponent_cash": 31435.0, "opponent_workers": 0, "own_cash": 97227.0, "own_workers": 0, "ready_yield_units": 105, "step": 528}, {"animals": 17, "cash_margin": 71538.0, "crops": 58, "episode_id": "112113452", "opponent_cash": 36756.0, "opponent_workers": 0, "own_cash": 108294.0, "own_workers": 0, "ready_yield_units": 103, "step": 552}, {"animals": 17, "cash_margin": 75014.0, "crops": 58, "episode_id": "112113452", "opponent_cash": 43396.0, "opponent_workers": 0, "own_cash": 118410.0, "own_workers": 0, "ready_yield_units": 96, "step": 576}, {"animals": 17, "cash_margin": 76498.0, "crops": 58, "episode_id": "112113452", "opponent_cash": 52582.0, "opponent_workers": 0, "own_cash": 129080.0, "own_workers": 0, "ready_yield_units": 112, "step": 600}, {"animals": 17, "cash_margin": 76889.0, "crops": 58, "episode_id": "112113452", "opponent_cash": 59549.0, "opponent_workers": 0, "own_cash": 136438.0, "own_workers": 0, "ready_yield_units": 101, "step": 624}, {"animals": 17, "cash_margin": 80025.0, "crops": 58, "episode_id": "112113452", "opponent_cash": 64891.0, "opponent_workers": 0, "own_cash": 144916.0, "own_workers": 0, "ready_yield_units": 134, "step": 648}, {"animals": 17, "cash_margin": 85336.0, "crops": 46, "episode_id": "112113452", "opponent_cash": 68346.0, "opponent_workers": 0, "own_cash": 153682.0, "own_workers": 0, "ready_yield_units": 107, "step": 672}, {"animals": 17, "cash_margin": 91436.0, "crops": 21, "episode_id": "112113452", "opponent_cash": 74709.0, "opponent_workers": 0, "own_cash": 166145.0, "own_workers": 0, "ready_yield_units": 66, "step": 696}, {"animals": 17, "cash_margin": 98651.0, "crops": 0, "episode_id": "112113452", "opponent_cash": 80252.0, "opponent_workers": 12, "own_cash": 178903.0, "own_workers": 11, "ready_yield_units": 0, "step": 718}], "episode_id": "112113452", "identity_basis": "target_submission_listing_plus_unique_team_name", "interpretation": "Descriptive time-selected public-game sample; not a rating estimate or causal policy test.", "listing_membership_verified": true, "opponent_reward": 80252.0, "outcome": "WIN", "own_reward": 179870.0, "seat": 0, "statuses": ["DONE", "DONE"], "submission_ref": "56471163"}, {"cash_margin": 42802.0, "daily": [{"animals": 0, "cash_margin": 0.0, "crops": 0, "episode_id": "112114637", "opponent_cash": 3000.0, "opponent_workers": 0, "own_cash": 3000.0, "own_workers": 0, "ready_yield_units": 0, "step": 0}, {"animals": 4, "cash_margin": -4.0, "crops": 20, "episode_id": "112114637", "opponent_cash": 19.0, "opponent_workers": 0, "own_cash": 15.0, "own_workers": 0, "ready_yield_units": 20, "step": 24}, {"animals": 4, "cash_margin": 89.0, "crops": 20, "episode_id": "112114637", "opponent_cash": 19.0, "opponent_workers": 0, "own_cash": 108.0, "own_workers": 0, "ready_yield_units": 20, "step": 48}, {"animals": 5, "cash_margin": 78.0, "crops": 20, "episode_id": "112114637", "opponent_cash": 144.0, "opponent_workers": 0, "own_cash": 222.0, "own_workers": 0, "ready_yield_units": 25, "step": 72}, {"animals": 6, "cash_margin": -46.0, "crops": 19, "episode_id": "112114637", "opponent_cash": 412.0, "opponent_workers": 0, "own_cash": 366.0, "own_workers": 0, "ready_yield_units": 19, "step": 96}, {"animals": 6, "cash_margin": 90.0, "crops": 19, "episode_id": "112114637", "opponent_cash": 687.0, "opponent_workers": 0, "own_cash": 777.0, "own_workers": 0, "ready_yield_units": 19, "step": 120}, {"animals": 6, "cash_margin": -780.0, "crops": 19, "episode_id": "112114637", "opponent_cash": 1670.0, "opponent_workers": 0, "own_cash": 890.0, "own_workers": 0, "ready_yield_units": 27, "step": 144}, {"animals": 8, "cash_margin": -671.0, "crops": 29, "episode_id": "112114637", "opponent_cash": 1918.0, "opponent_workers": 0, "own_cash": 1247.0, "own_workers": 0, "ready_yield_units": 29, "step": 168}, {"animals": 10, "cash_margin": 462.0, "crops": 37, "episode_id": "112114637", "opponent_cash": 221.0, "opponent_workers": 0, "own_cash": 683.0, "own_workers": 0, "ready_yield_units": 57, "step": 192}, {"animals": 12, "cash_margin": 1718.0, "crops": 37, "episode_id": "112114637", "opponent_cash": 4.0, "opponent_workers": 0, "own_cash": 1722.0, "own_workers": 0, "ready_yield_units": 61, "step": 216}, {"animals": 13, "cash_margin": 784.0, "crops": 37, "episode_id": "112114637", "opponent_cash": 1941.0, "opponent_workers": 0, "own_cash": 2725.0, "own_workers": 0, "ready_yield_units": 77, "step": 240}, {"animals": 16, "cash_margin": 6090.0, "crops": 32, "episode_id": "112114637", "opponent_cash": 12124.0, "opponent_workers": 0, "own_cash": 18214.0, "own_workers": 0, "ready_yield_units": 19, "step": 264}, {"animals": 17, "cash_margin": 10173.0, "crops": 53, "episode_id": "112114637", "opponent_cash": 7476.0, "opponent_workers": 0, "own_cash": 17649.0, "own_workers": 0, "ready_yield_units": 39, "step": 288}, {"animals": 17, "cash_margin": 14029.0, "crops": 57, "episode_id": "112114637", "opponent_cash": 7644.0, "opponent_workers": 0, "own_cash": 21673.0, "own_workers": 0, "ready_yield_units": 35, "step": 312}, {"animals": 17, "cash_margin": 14638.0, "crops": 57, "episode_id": "112114637", "opponent_cash": 9086.0, "opponent_workers": 0, "own_cash": 23724.0, "own_workers": 0, "ready_yield_units": 75, "step": 336}, {"animals": 17, "cash_margin": 15683.0, "crops": 57, "episode_id": "112114637", "opponent_cash": 11735.0, "opponent_workers": 0, "own_cash": 27418.0, "own_workers": 0, "ready_yield_units": 85, "step": 360}, {"animals": 17, "cash_margin": 20042.0, "crops": 57, "episode_id": "112114637", "opponent_cash": 12212.0, "opponent_workers": 0, "own_cash": 32254.0, "own_workers": 0, "ready_yield_units": 86, "step": 384}, {"animals": 17, "cash_margin": 24457.0, "crops": 58, "episode_id": "112114637", "opponent_cash": 13211.0, "opponent_workers": 0, "own_cash": 37668.0, "own_workers": 0, "ready_yield_units": 79, "step": 408}, {"animals": 17, "cash_margin": 25151.0, "crops": 58, "episode_id": "112114637", "opponent_cash": 16211.0, "opponent_workers": 0, "own_cash": 41362.0, "own_workers": 0, "ready_yield_units": 97, "step": 432}, {"animals": 17, "cash_margin": 26410.0, "crops": 58, "episode_id": "112114637", "opponent_cash": 19023.0, "opponent_workers": 0, "own_cash": 45433.0, "own_workers": 0, "ready_yield_units": 79, "step": 456}, {"animals": 17, "cash_margin": 27164.0, "crops": 58, "episode_id": "112114637", "opponent_cash": 21005.0, "opponent_workers": 0, "own_cash": 48169.0, "own_workers": 0, "ready_yield_units": 90, "step": 480}, {"animals": 17, "cash_margin": 26327.0, "crops": 58, "episode_id": "112114637", "opponent_cash": 23439.0, "opponent_workers": 0, "own_cash": 49766.0, "own_workers": 0, "ready_yield_units": 113, "step": 504}, {"animals": 17, "cash_margin": 27276.0, "crops": 57, "episode_id": "112114637", "opponent_cash": 23889.0, "opponent_workers": 0, "own_cash": 51165.0, "own_workers": 0, "ready_yield_units": 101, "step": 528}, {"animals": 17, "cash_margin": 29478.0, "crops": 58, "episode_id": "112114637", "opponent_cash": 23320.0, "opponent_workers": 0, "own_cash": 52798.0, "own_workers": 0, "ready_yield_units": 101, "step": 552}, {"animals": 17, "cash_margin": 31632.0, "crops": 58, "episode_id": "112114637", "opponent_cash": 23079.0, "opponent_workers": 0, "own_cash": 54711.0, "own_workers": 0, "ready_yield_units": 103, "step": 576}, {"animals": 17, "cash_margin": 32968.0, "crops": 58, "episode_id": "112114637", "opponent_cash": 22981.0, "opponent_workers": 0, "own_cash": 55949.0, "own_workers": 0, "ready_yield_units": 116, "step": 600}, {"animals": 17, "cash_margin": 34465.0, "crops": 58, "episode_id": "112114637", "opponent_cash": 23730.0, "opponent_workers": 0, "own_cash": 58195.0, "own_workers": 0, "ready_yield_units": 104, "step": 624}, {"animals": 16, "cash_margin": 36136.0, "crops": 58, "episode_id": "112114637", "opponent_cash": 24418.0, "opponent_workers": 0, "own_cash": 60554.0, "own_workers": 0, "ready_yield_units": 134, "step": 648}, {"animals": 16, "cash_margin": 37859.0, "crops": 45, "episode_id": "112114637", "opponent_cash": 25248.0, "opponent_workers": 0, "own_cash": 63107.0, "own_workers": 0, "ready_yield_units": 99, "step": 672}, {"animals": 16, "cash_margin": 40679.0, "crops": 21, "episode_id": "112114637", "opponent_cash": 26541.0, "opponent_workers": 0, "own_cash": 67220.0, "own_workers": 0, "ready_yield_units": 58, "step": 696}, {"animals": 16, "cash_margin": 42835.0, "crops": 0, "episode_id": "112114637", "opponent_cash": 32298.0, "opponent_workers": 11, "own_cash": 75133.0, "own_workers": 11, "ready_yield_units": 0, "step": 718}], "episode_id": "112114637", "identity_basis": "target_submission_listing_plus_unique_team_name", "interpretation": "Descriptive time-selected public-game sample; not a rating estimate or causal policy test.", "listing_membership_verified": true, "opponent_reward": 32648.0, "outcome": "WIN", "own_reward": 75450.0, "seat": 0, "statuses": ["DONE", "DONE"], "submission_ref": "56471163"}, {"cash_margin": 52627.0, "daily": [{"animals": 0, "cash_margin": 0.0, "crops": 0, "episode_id": "112115754", "opponent_cash": 3000.0, "opponent_workers": 0, "own_cash": 3000.0, "own_workers": 0, "ready_yield_units": 0, "step": 0}, {"animals": 4, "cash_margin": -28.0, "crops": 20, "episode_id": "112115754", "opponent_cash": 43.0, "opponent_workers": 0, "own_cash": 15.0, "own_workers": 0, "ready_yield_units": 20, "step": 24}, {"animals": 4, "cash_margin": -41.0, "crops": 20, "episode_id": "112115754", "opponent_cash": 137.0, "opponent_workers": 0, "own_cash": 96.0, "own_workers": 0, "ready_yield_units": 20, "step": 48}, {"animals": 5, "cash_margin": 0.0, "crops": 20, "episode_id": "112115754", "opponent_cash": 212.0, "opponent_workers": 0, "own_cash": 212.0, "own_workers": 0, "ready_yield_units": 25, "step": 72}, {"animals": 6, "cash_margin": -424.0, "crops": 19, "episode_id": "112115754", "opponent_cash": 786.0, "opponent_workers": 0, "own_cash": 362.0, "own_workers": 0, "ready_yield_units": 19, "step": 96}, {"animals": 6, "cash_margin": 145.0, "crops": 19, "episode_id": "112115754", "opponent_cash": 616.0, "opponent_workers": 0, "own_cash": 761.0, "own_workers": 0, "ready_yield_units": 19, "step": 120}, {"animals": 6, "cash_margin": 245.0, "crops": 19, "episode_id": "112115754", "opponent_cash": 630.0, "opponent_workers": 0, "own_cash": 875.0, "own_workers": 0, "ready_yield_units": 27, "step": 144}, {"animals": 8, "cash_margin": -269.0, "crops": 29, "episode_id": "112115754", "opponent_cash": 1558.0, "opponent_workers": 0, "own_cash": 1289.0, "own_workers": 0, "ready_yield_units": 29, "step": 168}, {"animals": 10, "cash_margin": -30.0, "crops": 37, "episode_id": "112115754", "opponent_cash": 750.0, "opponent_workers": 0, "own_cash": 720.0, "own_workers": 0, "ready_yield_units": 57, "step": 192}, {"animals": 12, "cash_margin": 1240.0, "crops": 37, "episode_id": "112115754", "opponent_cash": 448.0, "opponent_workers": 0, "own_cash": 1688.0, "own_workers": 0, "ready_yield_units": 61, "step": 216}, {"animals": 13, "cash_margin": 2593.0, "crops": 37, "episode_id": "112115754", "opponent_cash": 139.0, "opponent_workers": 0, "own_cash": 2732.0, "own_workers": 0, "ready_yield_units": 77, "step": 240}, {"animals": 16, "cash_margin": 16167.0, "crops": 32, "episode_id": "112115754", "opponent_cash": 1291.0, "opponent_workers": 0, "own_cash": 17458.0, "own_workers": 0, "ready_yield_units": 19, "step": 264}, {"animals": 17, "cash_margin": 13540.0, "crops": 53, "episode_id": "112115754", "opponent_cash": 3855.0, "opponent_workers": 0, "own_cash": 17395.0, "own_workers": 0, "ready_yield_units": 39, "step": 288}, {"animals": 17, "cash_margin": 11720.0, "crops": 57, "episode_id": "112115754", "opponent_cash": 10013.0, "opponent_workers": 0, "own_cash": 21733.0, "own_workers": 0, "ready_yield_units": 35, "step": 312}, {"animals": 17, "cash_margin": 15673.0, "crops": 57, "episode_id": "112115754", "opponent_cash": 7689.0, "opponent_workers": 0, "own_cash": 23362.0, "own_workers": 0, "ready_yield_units": 67, "step": 336}, {"animals": 17, "cash_margin": 14496.0, "crops": 57, "episode_id": "112115754", "opponent_cash": 13664.0, "opponent_workers": 0, "own_cash": 28160.0, "own_workers": 0, "ready_yield_units": 77, "step": 360}, {"animals": 17, "cash_margin": 15641.0, "crops": 57, "episode_id": "112115754", "opponent_cash": 16260.0, "opponent_workers": 0, "own_cash": 31901.0, "own_workers": 0, "ready_yield_units": 90, "step": 384}, {"animals": 17, "cash_margin": 23186.0, "crops": 58, "episode_id": "112115754", "opponent_cash": 17347.0, "opponent_workers": 0, "own_cash": 40533.0, "own_workers": 0, "ready_yield_units": 77, "step": 408}, {"animals": 17, "cash_margin": 27430.0, "crops": 58, "episode_id": "112115754", "opponent_cash": 21599.0, "opponent_workers": 0, "own_cash": 49029.0, "own_workers": 0, "ready_yield_units": 89, "step": 432}, {"animals": 17, "cash_margin": 29137.0, "crops": 58, "episode_id": "112115754", "opponent_cash": 25198.0, "opponent_workers": 0, "own_cash": 54335.0, "own_workers": 0, "ready_yield_units": 76, "step": 456}, {"animals": 17, "cash_margin": 31723.0, "crops": 58, "episode_id": "112115754", "opponent_cash": 27849.0, "opponent_workers": 0, "own_cash": 59572.0, "own_workers": 0, "ready_yield_units": 89, "step": 480}, {"animals": 17, "cash_margin": 31148.0, "crops": 58, "episode_id": "112115754", "opponent_cash": 34268.0, "opponent_workers": 0, "own_cash": 65416.0, "own_workers": 0, "ready_yield_units": 107, "step": 504}, {"animals": 17, "cash_margin": 34180.0, "crops": 57, "episode_id": "112115754", "opponent_cash": 38015.0, "opponent_workers": 0, "own_cash": 72195.0, "own_workers": 0, "ready_yield_units": 100, "step": 528}, {"animals": 17, "cash_margin": 38723.0, "crops": 58, "episode_id": "112115754", "opponent_cash": 37201.0, "opponent_workers": 0, "own_cash": 75924.0, "own_workers": 0, "ready_yield_units": 101, "step": 552}, {"animals": 17, "cash_margin": 39962.0, "crops": 58, "episode_id": "112115754", "opponent_cash": 39913.0, "opponent_workers": 0, "own_cash": 79875.0, "own_workers": 0, "ready_yield_units": 97, "step": 576}, {"animals": 17, "cash_margin": 40162.0, "crops": 58, "episode_id": "112115754", "opponent_cash": 41977.0, "opponent_workers": 0, "own_cash": 82139.0, "own_workers": 0, "ready_yield_units": 118, "step": 600}, {"animals": 17, "cash_margin": 43904.0, "crops": 58, "episode_id": "112115754", "opponent_cash": 40940.0, "opponent_workers": 0, "own_cash": 84844.0, "own_workers": 0, "ready_yield_units": 101, "step": 624}, {"animals": 17, "cash_margin": 45659.0, "crops": 58, "episode_id": "112115754", "opponent_cash": 41704.0, "opponent_workers": 0, "own_cash": 87363.0, "own_workers": 0, "ready_yield_units": 131, "step": 648}, {"animals": 17, "cash_margin": 47950.0, "crops": 46, "episode_id": "112115754", "opponent_cash": 42687.0, "opponent_workers": 0, "own_cash": 90637.0, "own_workers": 0, "ready_yield_units": 104, "step": 672}, {"animals": 17, "cash_margin": 51190.0, "crops": 21, "episode_id": "112115754", "opponent_cash": 43633.0, "opponent_workers": 0, "own_cash": 94823.0, "own_workers": 0, "ready_yield_units": 63, "step": 696}, {"animals": 17, "cash_margin": 52370.0, "crops": 0, "episode_id": "112115754", "opponent_cash": 50546.0, "opponent_workers": 12, "own_cash": 102916.0, "own_workers": 11, "ready_yield_units": 0, "step": 718}], "episode_id": "112115754", "identity_basis": "target_submission_listing_plus_unique_team_name", "interpretation": "Descriptive time-selected public-game sample; not a rating estimate or causal policy test.", "listing_membership_verified": true, "opponent_reward": 50560.0, "outcome": "WIN", "own_reward": 103187.0, "seat": 0, "statuses": ["DONE", "DONE"], "submission_ref": "56471163"}, {"cash_margin": 41561.0, "daily": [{"animals": 0, "cash_margin": 0.0, "crops": 0, "episode_id": "112119192", "opponent_cash": 3000.0, "opponent_workers": 0, "own_cash": 3000.0, "own_workers": 0, "ready_yield_units": 0, "step": 0}, {"animals": 4, "cash_margin": -3.0, "crops": 20, "episode_id": "112119192", "opponent_cash": 18.0, "opponent_workers": 0, "own_cash": 15.0, "own_workers": 0, "ready_yield_units": 20, "step": 24}, {"animals": 4, "cash_margin": -63.0, "crops": 20, "episode_id": "112119192", "opponent_cash": 167.0, "opponent_workers": 0, "own_cash": 104.0, "own_workers": 0, "ready_yield_units": 20, "step": 48}, {"animals": 5, "cash_margin": -3.0, "crops": 20, "episode_id": "112119192", "opponent_cash": 220.0, "opponent_workers": 0, "own_cash": 217.0, "own_workers": 0, "ready_yield_units": 25, "step": 72}, {"animals": 6, "cash_margin": 92.0, "crops": 19, "episode_id": "112119192", "opponent_cash": 262.0, "opponent_workers": 0, "own_cash": 354.0, "own_workers": 0, "ready_yield_units": 19, "step": 96}, {"animals": 6, "cash_margin": 419.0, "crops": 19, "episode_id": "112119192", "opponent_cash": 346.0, "opponent_workers": 0, "own_cash": 765.0, "own_workers": 0, "ready_yield_units": 19, "step": 120}, {"animals": 6, "cash_margin": 423.0, "crops": 19, "episode_id": "112119192", "opponent_cash": 455.0, "opponent_workers": 0, "own_cash": 878.0, "own_workers": 0, "ready_yield_units": 27, "step": 144}, {"animals": 8, "cash_margin": 666.0, "crops": 29, "episode_id": "112119192", "opponent_cash": 787.0, "opponent_workers": 0, "own_cash": 1453.0, "own_workers": 0, "ready_yield_units": 29, "step": 168}, {"animals": 10, "cash_margin": 614.0, "crops": 37, "episode_id": "112119192", "opponent_cash": 99.0, "opponent_workers": 0, "own_cash": 713.0, "own_workers": 0, "ready_yield_units": 57, "step": 192}, {"animals": 12, "cash_margin": 300.0, "crops": 37, "episode_id": "112119192", "opponent_cash": 872.0, "opponent_workers": 0, "own_cash": 1172.0, "own_workers": 0, "ready_yield_units": 61, "step": 216}, {"animals": 13, "cash_margin": -101.0, "crops": 37, "episode_id": "112119192", "opponent_cash": 2028.0, "opponent_workers": 0, "own_cash": 1927.0, "own_workers": 0, "ready_yield_units": 84, "step": 240}, {"animals": 16, "cash_margin": 416.0, "crops": 32, "episode_id": "112119192", "opponent_cash": 13969.0, "opponent_workers": 0, "own_cash": 14385.0, "own_workers": 0, "ready_yield_units": 25, "step": 264}, {"animals": 17, "cash_margin": 2030.0, "crops": 53, "episode_id": "112119192", "opponent_cash": 11054.0, "opponent_workers": 0, "own_cash": 13084.0, "own_workers": 0, "ready_yield_units": 46, "step": 288}, {"animals": 17, "cash_margin": 1377.0, "crops": 57, "episode_id": "112119192", "opponent_cash": 14318.0, "opponent_workers": 0, "own_cash": 15695.0, "own_workers": 0, "ready_yield_units": 43, "step": 312}, {"animals": 17, "cash_margin": 1016.0, "crops": 57, "episode_id": "112119192", "opponent_cash": 15909.0, "opponent_workers": 0, "own_cash": 16925.0, "own_workers": 0, "ready_yield_units": 67, "step": 336}, {"animals": 17, "cash_margin": 927.0, "crops": 57, "episode_id": "112119192", "opponent_cash": 17074.0, "opponent_workers": 0, "own_cash": 18001.0, "own_workers": 0, "ready_yield_units": 86, "step": 360}, {"animals": 17, "cash_margin": 3141.0, "crops": 57, "episode_id": "112119192", "opponent_cash": 17440.0, "opponent_workers": 0, "own_cash": 20581.0, "own_workers": 0, "ready_yield_units": 87, "step": 384}, {"animals": 17, "cash_margin": 2394.0, "crops": 58, "episode_id": "112119192", "opponent_cash": 20361.0, "opponent_workers": 0, "own_cash": 22755.0, "own_workers": 0, "ready_yield_units": 74, "step": 408}, {"animals": 17, "cash_margin": 3005.0, "crops": 58, "episode_id": "112119192", "opponent_cash": 21466.0, "opponent_workers": 0, "own_cash": 24471.0, "own_workers": 0, "ready_yield_units": 90, "step": 432}, {"animals": 17, "cash_margin": 4637.0, "crops": 58, "episode_id": "112119192", "opponent_cash": 21704.0, "opponent_workers": 0, "own_cash": 26341.0, "own_workers": 0, "ready_yield_units": 79, "step": 456}, {"animals": 17, "cash_margin": 5724.0, "crops": 58, "episode_id": "112119192", "opponent_cash": 21843.0, "opponent_workers": 0, "own_cash": 27567.0, "own_workers": 0, "ready_yield_units": 91, "step": 480}, {"animals": 17, "cash_margin": 6387.0, "crops": 58, "episode_id": "112119192", "opponent_cash": 21813.0, "opponent_workers": 0, "own_cash": 28200.0, "own_workers": 0, "ready_yield_units": 108, "step": 504}, {"animals": 17, "cash_margin": 6682.0, "crops": 56, "episode_id": "112119192", "opponent_cash": 23097.0, "opponent_workers": 0, "own_cash": 29779.0, "own_workers": 0, "ready_yield_units": 93, "step": 528}, {"animals": 17, "cash_margin": 7588.0, "crops": 58, "episode_id": "112119192", "opponent_cash": 23271.0, "opponent_workers": 0, "own_cash": 30859.0, "own_workers": 0, "ready_yield_units": 101, "step": 552}, {"animals": 17, "cash_margin": 8884.0, "crops": 58, "episode_id": "112119192", "opponent_cash": 23377.0, "opponent_workers": 0, "own_cash": 32261.0, "own_workers": 0, "ready_yield_units": 97, "step": 576}, {"animals": 17, "cash_margin": 10015.0, "crops": 58, "episode_id": "112119192", "opponent_cash": 23257.0, "opponent_workers": 0, "own_cash": 33272.0, "own_workers": 0, "ready_yield_units": 112, "step": 600}, {"animals": 17, "cash_margin": 11858.0, "crops": 57, "episode_id": "112119192", "opponent_cash": 24482.0, "opponent_workers": 0, "own_cash": 36340.0, "own_workers": 0, "ready_yield_units": 95, "step": 624}, {"animals": 16, "cash_margin": 13835.0, "crops": 51, "episode_id": "112119192", "opponent_cash": 25190.0, "opponent_workers": 0, "own_cash": 39025.0, "own_workers": 0, "ready_yield_units": 102, "step": 648}, {"animals": 16, "cash_margin": 20506.0, "crops": 38, "episode_id": "112119192", "opponent_cash": 26036.0, "opponent_workers": 0, "own_cash": 46542.0, "own_workers": 0, "ready_yield_units": 73, "step": 672}, {"animals": 16, "cash_margin": 26904.0, "crops": 21, "episode_id": "112119192", "opponent_cash": 27856.0, "opponent_workers": 0, "own_cash": 54760.0, "own_workers": 0, "ready_yield_units": 64, "step": 696}, {"animals": 16, "cash_margin": 40303.0, "crops": 0, "episode_id": "112119192", "opponent_cash": 33494.0, "opponent_workers": 11, "own_cash": 73797.0, "own_workers": 11, "ready_yield_units": 0, "step": 718}], "episode_id": "112119192", "identity_basis": "target_submission_listing_plus_unique_team_name", "interpretation": "Descriptive time-selected public-game sample; not a rating estimate or causal policy test.", "listing_membership_verified": true, "opponent_reward": 33494.0, "outcome": "WIN", "own_reward": 75055.0, "seat": 0, "statuses": ["DONE", "DONE"], "submission_ref": "56471163"}, {"cash_margin": 14468.0, "daily": [{"animals": 0, "cash_margin": 0.0, "crops": 0, "episode_id": "112120315", "opponent_cash": 3000.0, "opponent_workers": 0, "own_cash": 3000.0, "own_workers": 0, "ready_yield_units": 0, "step": 0}, {"animals": 4, "cash_margin": -10.0, "crops": 20, "episode_id": "112120315", "opponent_cash": 22.0, "opponent_workers": 0, "own_cash": 12.0, "own_workers": 0, "ready_yield_units": 20, "step": 24}, {"animals": 4, "cash_margin": 50.0, "crops": 20, "episode_id": "112120315", "opponent_cash": 49.0, "opponent_workers": 0, "own_cash": 99.0, "own_workers": 0, "ready_yield_units": 20, "step": 48}, {"animals": 5, "cash_margin": 70.0, "crops": 20, "episode_id": "112120315", "opponent_cash": 142.0, "opponent_workers": 0, "own_cash": 212.0, "own_workers": 0, "ready_yield_units": 25, "step": 72}, {"animals": 6, "cash_margin": 138.0, "crops": 19, "episode_id": "112120315", "opponent_cash": 213.0, "opponent_workers": 0, "own_cash": 351.0, "own_workers": 0, "ready_yield_units": 19, "step": 96}, {"animals": 6, "cash_margin": 582.0, "crops": 19, "episode_id": "112120315", "opponent_cash": 179.0, "opponent_workers": 0, "own_cash": 761.0, "own_workers": 0, "ready_yield_units": 19, "step": 120}, {"animals": 6, "cash_margin": 435.0, "crops": 19, "episode_id": "112120315", "opponent_cash": 440.0, "opponent_workers": 0, "own_cash": 875.0, "own_workers": 0, "ready_yield_units": 27, "step": 144}, {"animals": 8, "cash_margin": 462.0, "crops": 29, "episode_id": "112120315", "opponent_cash": 1020.0, "opponent_workers": 0, "own_cash": 1482.0, "own_workers": 0, "ready_yield_units": 29, "step": 168}, {"animals": 10, "cash_margin": 20.0, "crops": 37, "episode_id": "112120315", "opponent_cash": 511.0, "opponent_workers": 0, "own_cash": 531.0, "own_workers": 0, "ready_yield_units": 57, "step": 192}, {"animals": 12, "cash_margin": 211.0, "crops": 37, "episode_id": "112120315", "opponent_cash": 1451.0, "opponent_workers": 0, "own_cash": 1662.0, "own_workers": 0, "ready_yield_units": 61, "step": 216}, {"animals": 13, "cash_margin": 2705.0, "crops": 37, "episode_id": "112120315", "opponent_cash": 1543.0, "opponent_workers": 0, "own_cash": 4248.0, "own_workers": 0, "ready_yield_units": 76, "step": 240}, {"animals": 16, "cash_margin": 4493.0, "crops": 32, "episode_id": "112120315", "opponent_cash": 12409.0, "opponent_workers": 0, "own_cash": 16902.0, "own_workers": 0, "ready_yield_units": 19, "step": 264}, {"animals": 23, "cash_margin": -3947.0, "crops": 53, "episode_id": "112120315", "opponent_cash": 11706.0, "opponent_workers": 0, "own_cash": 7759.0, "own_workers": 0, "ready_yield_units": 51, "step": 288}, {"animals": 23, "cash_margin": -5280.0, "crops": 57, "episode_id": "112120315", "opponent_cash": 17966.0, "opponent_workers": 0, "own_cash": 12686.0, "own_workers": 0, "ready_yield_units": 35, "step": 312}, {"animals": 23, "cash_margin": -5955.0, "crops": 57, "episode_id": "112120315", "opponent_cash": 20987.0, "opponent_workers": 0, "own_cash": 15032.0, "own_workers": 0, "ready_yield_units": 55, "step": 336}, {"animals": 23, "cash_margin": -6978.0, "crops": 57, "episode_id": "112120315", "opponent_cash": 25744.0, "opponent_workers": 0, "own_cash": 18766.0, "own_workers": 0, "ready_yield_units": 83, "step": 360}, {"animals": 23, "cash_margin": -5692.0, "crops": 58, "episode_id": "112120315", "opponent_cash": 30740.0, "opponent_workers": 0, "own_cash": 25048.0, "own_workers": 0, "ready_yield_units": 83, "step": 384}, {"animals": 23, "cash_margin": -4263.0, "crops": 58, "episode_id": "112120315", "opponent_cash": 39674.0, "opponent_workers": 0, "own_cash": 35411.0, "own_workers": 0, "ready_yield_units": 115, "step": 408}, {"animals": 23, "cash_margin": 5203.0, "crops": 58, "episode_id": "112120315", "opponent_cash": 46392.0, "opponent_workers": 0, "own_cash": 51595.0, "own_workers": 0, "ready_yield_units": 94, "step": 432}, {"animals": 23, "cash_margin": 4663.0, "crops": 58, "episode_id": "112120315", "opponent_cash": 53668.0, "opponent_workers": 0, "own_cash": 58331.0, "own_workers": 0, "ready_yield_units": 79, "step": 456}, {"animals": 23, "cash_margin": 2767.0, "crops": 58, "episode_id": "112120315", "opponent_cash": 59626.0, "opponent_workers": 0, "own_cash": 62393.0, "own_workers": 0, "ready_yield_units": 112, "step": 480}, {"animals": 23, "cash_margin": 8729.0, "crops": 58, "episode_id": "112120315", "opponent_cash": 63421.0, "opponent_workers": 0, "own_cash": 72150.0, "own_workers": 0, "ready_yield_units": 112, "step": 504}, {"animals": 23, "cash_margin": 6865.0, "crops": 57, "episode_id": "112120315", "opponent_cash": 67971.0, "opponent_workers": 0, "own_cash": 74836.0, "own_workers": 0, "ready_yield_units": 99, "step": 528}, {"animals": 23, "cash_margin": 8646.0, "crops": 58, "episode_id": "112120315", "opponent_cash": 71321.0, "opponent_workers": 0, "own_cash": 79967.0, "own_workers": 0, "ready_yield_units": 123, "step": 552}, {"animals": 23, "cash_margin": 11886.0, "crops": 58, "episode_id": "112120315", "opponent_cash": 76353.0, "opponent_workers": 0, "own_cash": 88239.0, "own_workers": 0, "ready_yield_units": 95, "step": 576}, {"animals": 23, "cash_margin": 11360.0, "crops": 58, "episode_id": "112120315", "opponent_cash": 80970.0, "opponent_workers": 0, "own_cash": 92330.0, "own_workers": 0, "ready_yield_units": 107, "step": 600}, {"animals": 23, "cash_margin": 9363.0, "crops": 58, "episode_id": "112120315", "opponent_cash": 86258.0, "opponent_workers": 0, "own_cash": 95621.0, "own_workers": 0, "ready_yield_units": 118, "step": 624}, {"animals": 23, "cash_margin": 11436.0, "crops": 58, "episode_id": "112120315", "opponent_cash": 89861.0, "opponent_workers": 0, "own_cash": 101297.0, "own_workers": 0, "ready_yield_units": 137, "step": 648}, {"animals": 23, "cash_margin": 11195.0, "crops": 46, "episode_id": "112120315", "opponent_cash": 92327.0, "opponent_workers": 0, "own_cash": 103522.0, "own_workers": 0, "ready_yield_units": 101, "step": 672}, {"animals": 23, "cash_margin": 12583.0, "crops": 21, "episode_id": "112120315", "opponent_cash": 94315.0, "opponent_workers": 0, "own_cash": 106898.0, "own_workers": 0, "ready_yield_units": 82, "step": 696}, {"animals": 23, "cash_margin": 14267.0, "crops": 0, "episode_id": "112120315", "opponent_cash": 98493.0, "opponent_workers": 11, "own_cash": 112760.0, "own_workers": 12, "ready_yield_units": 0, "step": 718}], "episode_id": "112120315", "identity_basis": "target_submission_listing_plus_unique_team_name", "interpretation": "Descriptive time-selected public-game sample; not a rating estimate or causal policy test.", "listing_membership_verified": true, "opponent_reward": 98541.0, "outcome": "WIN", "own_reward": 113009.0, "seat": 1, "statuses": ["DONE", "DONE"], "submission_ref": "56471163"}, {"cash_margin": 8069.0, "daily": [{"animals": 0, "cash_margin": 0.0, "crops": 0, "episode_id": "112121431", "opponent_cash": 3000.0, "opponent_workers": 0, "own_cash": 3000.0, "own_workers": 0, "ready_yield_units": 0, "step": 0}, {"animals": 4, "cash_margin": -30.0, "crops": 20, "episode_id": "112121431", "opponent_cash": 34.0, "opponent_workers": 0, "own_cash": 4.0, "own_workers": 0, "ready_yield_units": 20, "step": 24}, {"animals": 4, "cash_margin": -1.0, "crops": 20, "episode_id": "112121431", "opponent_cash": 94.0, "opponent_workers": 0, "own_cash": 93.0, "own_workers": 0, "ready_yield_units": 20, "step": 48}, {"animals": 5, "cash_margin": -1.0, "crops": 20, "episode_id": "112121431", "opponent_cash": 207.0, "opponent_workers": 0, "own_cash": 206.0, "own_workers": 0, "ready_yield_units": 25, "step": 72}, {"animals": 6, "cash_margin": 59.0, "crops": 19, "episode_id": "112121431", "opponent_cash": 290.0, "opponent_workers": 0, "own_cash": 349.0, "own_workers": 0, "ready_yield_units": 19, "step": 96}, {"animals": 6, "cash_margin": 60.0, "crops": 19, "episode_id": "112121431", "opponent_cash": 696.0, "opponent_workers": 0, "own_cash": 756.0, "own_workers": 0, "ready_yield_units": 19, "step": 120}, {"animals": 6, "cash_margin": 60.0, "crops": 19, "episode_id": "112121431", "opponent_cash": 811.0, "opponent_workers": 0, "own_cash": 871.0, "own_workers": 0, "ready_yield_units": 27, "step": 144}, {"animals": 8, "cash_margin": 258.0, "crops": 29, "episode_id": "112121431", "opponent_cash": 874.0, "opponent_workers": 0, "own_cash": 1132.0, "own_workers": 0, "ready_yield_units": 29, "step": 168}, {"animals": 10, "cash_margin": -253.0, "crops": 37, "episode_id": "112121431", "opponent_cash": 413.0, "opponent_workers": 0, "own_cash": 160.0, "own_workers": 0, "ready_yield_units": 57, "step": 192}, {"animals": 12, "cash_margin": 285.0, "crops": 37, "episode_id": "112121431", "opponent_cash": 820.0, "opponent_workers": 0, "own_cash": 1105.0, "own_workers": 0, "ready_yield_units": 61, "step": 216}, {"animals": 13, "cash_margin": 1687.0, "crops": 37, "episode_id": "112121431", "opponent_cash": 1951.0, "opponent_workers": 0, "own_cash": 3638.0, "own_workers": 0, "ready_yield_units": 76, "step": 240}, {"animals": 16, "cash_margin": 2312.0, "crops": 32, "episode_id": "112121431", "opponent_cash": 13197.0, "opponent_workers": 0, "own_cash": 15509.0, "own_workers": 0, "ready_yield_units": 19, "step": 264}, {"animals": 17, "cash_margin": 2516.0, "crops": 53, "episode_id": "112121431", "opponent_cash": 10978.0, "opponent_workers": 0, "own_cash": 13494.0, "own_workers": 0, "ready_yield_units": 51, "step": 288}, {"animals": 17, "cash_margin": 3627.0, "crops": 57, "episode_id": "112121431", "opponent_cash": 14077.0, "opponent_workers": 0, "own_cash": 17704.0, "own_workers": 0, "ready_yield_units": 35, "step": 312}, {"animals": 17, "cash_margin": 3759.0, "crops": 57, "episode_id": "112121431", "opponent_cash": 15826.0, "opponent_workers": 0, "own_cash": 19585.0, "own_workers": 0, "ready_yield_units": 55, "step": 336}, {"animals": 17, "cash_margin": 3825.0, "crops": 57, "episode_id": "112121431", "opponent_cash": 18651.0, "opponent_workers": 0, "own_cash": 22476.0, "own_workers": 0, "ready_yield_units": 82, "step": 360}, {"animals": 17, "cash_margin": 901.0, "crops": 58, "episode_id": "112121431", "opponent_cash": 26462.0, "opponent_workers": 0, "own_cash": 27363.0, "own_workers": 0, "ready_yield_units": 80, "step": 384}, {"animals": 17, "cash_margin": 4624.0, "crops": 58, "episode_id": "112121431", "opponent_cash": 30966.0, "opponent_workers": 0, "own_cash": 35590.0, "own_workers": 0, "ready_yield_units": 76, "step": 408}, {"animals": 17, "cash_margin": 3107.0, "crops": 58, "episode_id": "112121431", "opponent_cash": 37547.0, "opponent_workers": 0, "own_cash": 40654.0, "own_workers": 0, "ready_yield_units": 91, "step": 432}, {"animals": 17, "cash_margin": 3608.0, "crops": 58, "episode_id": "112121431", "opponent_cash": 40210.0, "opponent_workers": 0, "own_cash": 43818.0, "own_workers": 0, "ready_yield_units": 76, "step": 456}, {"animals": 17, "cash_margin": 4080.0, "crops": 58, "episode_id": "112121431", "opponent_cash": 40570.0, "opponent_workers": 0, "own_cash": 44650.0, "own_workers": 0, "ready_yield_units": 85, "step": 480}, {"animals": 17, "cash_margin": 5087.0, "crops": 58, "episode_id": "112121431", "opponent_cash": 41121.0, "opponent_workers": 0, "own_cash": 46208.0, "own_workers": 0, "ready_yield_units": 104, "step": 504}, {"animals": 17, "cash_margin": 3202.0, "crops": 57, "episode_id": "112121431", "opponent_cash": 42793.0, "opponent_workers": 0, "own_cash": 45995.0, "own_workers": 0, "ready_yield_units": 92, "step": 528}, {"animals": 17, "cash_margin": 4350.0, "crops": 58, "episode_id": "112121431", "opponent_cash": 43557.0, "opponent_workers": 0, "own_cash": 47907.0, "own_workers": 0, "ready_yield_units": 98, "step": 552}, {"animals": 17, "cash_margin": 3553.0, "crops": 58, "episode_id": "112121431", "opponent_cash": 45321.0, "opponent_workers": 0, "own_cash": 48874.0, "own_workers": 0, "ready_yield_units": 99, "step": 576}, {"animals": 17, "cash_margin": 4077.0, "crops": 58, "episode_id": "112121431", "opponent_cash": 46967.0, "opponent_workers": 0, "own_cash": 51044.0, "own_workers": 0, "ready_yield_units": 114, "step": 600}, {"animals": 17, "cash_margin": 4511.0, "crops": 58, "episode_id": "112121431", "opponent_cash": 47728.0, "opponent_workers": 0, "own_cash": 52239.0, "own_workers": 0, "ready_yield_units": 90, "step": 624}, {"animals": 17, "cash_margin": 3958.0, "crops": 58, "episode_id": "112121431", "opponent_cash": 48720.0, "opponent_workers": 0, "own_cash": 52678.0, "own_workers": 0, "ready_yield_units": 137, "step": 648}, {"animals": 17, "cash_margin": 6148.0, "crops": 46, "episode_id": "112121431", "opponent_cash": 49466.0, "opponent_workers": 0, "own_cash": 55614.0, "own_workers": 0, "ready_yield_units": 98, "step": 672}, {"animals": 17, "cash_margin": 7976.0, "crops": 21, "episode_id": "112121431", "opponent_cash": 52310.0, "opponent_workers": 0, "own_cash": 60286.0, "own_workers": 0, "ready_yield_units": 55, "step": 696}, {"animals": 17, "cash_margin": 8396.0, "crops": 0, "episode_id": "112121431", "opponent_cash": 57803.0, "opponent_workers": 11, "own_cash": 66199.0, "own_workers": 11, "ready_yield_units": 0, "step": 718}], "episode_id": "112121431", "identity_basis": "target_submission_listing_plus_unique_team_name", "interpretation": "Descriptive time-selected public-game sample; not a rating estimate or causal policy test.", "listing_membership_verified": true, "opponent_reward": 58573.0, "outcome": "WIN", "own_reward": 66642.0, "seat": 1, "statuses": ["DONE", "DONE"], "submission_ref": "56471163"}, {"cash_margin": 35053.0, "daily": [{"animals": 0, "cash_margin": 0.0, "crops": 0, "episode_id": "112122469", "opponent_cash": 3000.0, "opponent_workers": 0, "own_cash": 3000.0, "own_workers": 0, "ready_yield_units": 0, "step": 0}, {"animals": 4, "cash_margin": 8.0, "crops": 20, "episode_id": "112122469", "opponent_cash": 19.0, "opponent_workers": 0, "own_cash": 27.0, "own_workers": 0, "ready_yield_units": 20, "step": 24}, {"animals": 4, "cash_margin": -353.0, "crops": 20, "episode_id": "112122469", "opponent_cash": 439.0, "opponent_workers": 0, "own_cash": 86.0, "own_workers": 0, "ready_yield_units": 20, "step": 48}, {"animals": 5, "cash_margin": -627.0, "crops": 20, "episode_id": "112122469", "opponent_cash": 822.0, "opponent_workers": 0, "own_cash": 195.0, "own_workers": 0, "ready_yield_units": 25, "step": 72}, {"animals": 6, "cash_margin": -816.0, "crops": 19, "episode_id": "112122469", "opponent_cash": 1188.0, "opponent_workers": 0, "own_cash": 372.0, "own_workers": 0, "ready_yield_units": 19, "step": 96}, {"animals": 6, "cash_margin": 609.0, "crops": 19, "episode_id": "112122469", "opponent_cash": 157.0, "opponent_workers": 0, "own_cash": 766.0, "own_workers": 0, "ready_yield_units": 19, "step": 120}, {"animals": 6, "cash_margin": 610.0, "crops": 19, "episode_id": "112122469", "opponent_cash": 251.0, "opponent_workers": 0, "own_cash": 861.0, "own_workers": 0, "ready_yield_units": 27, "step": 144}, {"animals": 8, "cash_margin": -687.0, "crops": 29, "episode_id": "112122469", "opponent_cash": 1646.0, "opponent_workers": 0, "own_cash": 959.0, "own_workers": 0, "ready_yield_units": 29, "step": 168}, {"animals": 10, "cash_margin": -687.0, "crops": 37, "episode_id": "112122469", "opponent_cash": 689.0, "opponent_workers": 0, "own_cash": 2.0, "own_workers": 0, "ready_yield_units": 57, "step": 192}, {"animals": 12, "cash_margin": -45.0, "crops": 37, "episode_id": "112122469", "opponent_cash": 1006.0, "opponent_workers": 0, "own_cash": 961.0, "own_workers": 0, "ready_yield_units": 61, "step": 216}, {"animals": 13, "cash_margin": -560.0, "crops": 37, "episode_id": "112122469", "opponent_cash": 3979.0, "opponent_workers": 0, "own_cash": 3419.0, "own_workers": 0, "ready_yield_units": 76, "step": 240}, {"animals": 16, "cash_margin": 13610.0, "crops": 32, "episode_id": "112122469", "opponent_cash": 3457.0, "opponent_workers": 0, "own_cash": 17067.0, "own_workers": 0, "ready_yield_units": 19, "step": 264}, {"animals": 17, "cash_margin": 11524.0, "crops": 53, "episode_id": "112122469", "opponent_cash": 4904.0, "opponent_workers": 0, "own_cash": 16428.0, "own_workers": 0, "ready_yield_units": 51, "step": 288}, {"animals": 17, "cash_margin": 12631.0, "crops": 57, "episode_id": "112122469", "opponent_cash": 7835.0, "opponent_workers": 0, "own_cash": 20466.0, "own_workers": 0, "ready_yield_units": 35, "step": 312}, {"animals": 17, "cash_margin": 14911.0, "crops": 57, "episode_id": "112122469", "opponent_cash": 7716.0, "opponent_workers": 0, "own_cash": 22627.0, "own_workers": 0, "ready_yield_units": 55, "step": 336}, {"animals": 17, "cash_margin": 14899.0, "crops": 57, "episode_id": "112122469", "opponent_cash": 10662.0, "opponent_workers": 0, "own_cash": 25561.0, "own_workers": 0, "ready_yield_units": 83, "step": 360}, {"animals": 17, "cash_margin": 17454.0, "crops": 58, "episode_id": "112122469", "opponent_cash": 12979.0, "opponent_workers": 0, "own_cash": 30433.0, "own_workers": 0, "ready_yield_units": 80, "step": 384}, {"animals": 17, "cash_margin": 21580.0, "crops": 58, "episode_id": "112122469", "opponent_cash": 17993.0, "opponent_workers": 0, "own_cash": 39573.0, "own_workers": 0, "ready_yield_units": 76, "step": 408}, {"animals": 17, "cash_margin": 22218.0, "crops": 58, "episode_id": "112122469", "opponent_cash": 24100.0, "opponent_workers": 0, "own_cash": 46318.0, "own_workers": 0, "ready_yield_units": 91, "step": 432}, {"animals": 17, "cash_margin": 25300.0, "crops": 58, "episode_id": "112122469", "opponent_cash": 27537.0, "opponent_workers": 0, "own_cash": 52837.0, "own_workers": 0, "ready_yield_units": 76, "step": 456}, {"animals": 17, "cash_margin": 24700.0, "crops": 58, "episode_id": "112122469", "opponent_cash": 31837.0, "opponent_workers": 0, "own_cash": 56537.0, "own_workers": 0, "ready_yield_units": 85, "step": 480}, {"animals": 17, "cash_margin": 28019.0, "crops": 58, "episode_id": "112122469", "opponent_cash": 32336.0, "opponent_workers": 0, "own_cash": 60355.0, "own_workers": 0, "ready_yield_units": 109, "step": 504}, {"animals": 17, "cash_margin": 27963.0, "crops": 57, "episode_id": "112122469", "opponent_cash": 34929.0, "opponent_workers": 0, "own_cash": 62892.0, "own_workers": 0, "ready_yield_units": 96, "step": 528}, {"animals": 17, "cash_margin": 31380.0, "crops": 58, "episode_id": "112122469", "opponent_cash": 36065.0, "opponent_workers": 0, "own_cash": 67445.0, "own_workers": 0, "ready_yield_units": 98, "step": 552}, {"animals": 17, "cash_margin": 34282.0, "crops": 58, "episode_id": "112122469", "opponent_cash": 35920.0, "opponent_workers": 0, "own_cash": 70202.0, "own_workers": 0, "ready_yield_units": 99, "step": 576}, {"animals": 17, "cash_margin": 36922.0, "crops": 58, "episode_id": "112122469", "opponent_cash": 37688.0, "opponent_workers": 0, "own_cash": 74610.0, "own_workers": 0, "ready_yield_units": 114, "step": 600}, {"animals": 17, "cash_margin": 35642.0, "crops": 58, "episode_id": "112122469", "opponent_cash": 43170.0, "opponent_workers": 0, "own_cash": 78812.0, "own_workers": 0, "ready_yield_units": 97, "step": 624}, {"animals": 17, "cash_margin": 36273.0, "crops": 58, "episode_id": "112122469", "opponent_cash": 45123.0, "opponent_workers": 0, "own_cash": 81396.0, "own_workers": 0, "ready_yield_units": 139, "step": 648}, {"animals": 17, "cash_margin": 37218.0, "crops": 46, "episode_id": "112122469", "opponent_cash": 47464.0, "opponent_workers": 0, "own_cash": 84682.0, "own_workers": 0, "ready_yield_units": 102, "step": 672}, {"animals": 17, "cash_margin": 36483.0, "crops": 21, "episode_id": "112122469", "opponent_cash": 51654.0, "opponent_workers": 0, "own_cash": 88137.0, "own_workers": 0, "ready_yield_units": 61, "step": 696}, {"animals": 17, "cash_margin": 36850.0, "crops": 0, "episode_id": "112122469", "opponent_cash": 57349.0, "opponent_workers": 12, "own_cash": 94199.0, "own_workers": 11, "ready_yield_units": 0, "step": 718}], "episode_id": "112122469", "identity_basis": "target_submission_listing_plus_unique_team_name", "interpretation": "Descriptive time-selected public-game sample; not a rating estimate or causal policy test.", "listing_membership_verified": true, "opponent_reward": 59382.0, "outcome": "WIN", "own_reward": 94435.0, "seat": 0, "statuses": ["DONE", "DONE"], "submission_ref": "56471163"}], "return_bundle": "/home/sagemaker-user/kaggriculture_live_feedback_return_20260922T185337139777Z.zip", "run_id": "20260922T185337139777Z", "score": {"incumbent_same_listing": {"date": "2026-09-21T18:53:27.197000", "description": "Original sale timing | 1aa3717b | confirmed 20260921T174353846962Z", "fileName": "confirmed_original_controller.tar.gz", "privateScore": "", "publicScore": "2076.9", "ref": 56441483, "status": "SubmissionStatus.COMPLETE"}, "leaderboard": {"max_score_in_returned_rows": 3106.0, "reason": "no explicit rank-one row returned", "verified": false}, "observed_utc": "2026-09-22T18:54:50.853415+00:00", "rating_is_final_or_converged": false, "submission_attempted": false, "submission_ref": "56471163", "submissions": {"best_in_returned_listing": 2076.9, "best_row": {"date": "2026-09-21T18:53:27.197000", "description": "Original sale timing | 1aa3717b | confirmed 20260921T174353846962Z", "fileName": "confirmed_original_controller.tar.gz", "privateScore": "", "publicScore": "2076.9", "ref": 56441483, "status": "SubmissionStatus.COMPLETE"}, "scope": "returned listing only; not guaranteed full submission history", "target": {"date": "2026-09-22T17:58:41.503000", "description": "Frozen timing reference 9c0a8921aa49 | independent confirmation", "fileName": "confirmed_timing_reference.tar.gz", "privateScore": "", "publicScore": "1535.2", "ref": 56471163, "status": "SubmissionStatus.COMPLETE"}, "target_ref": "56471163"}, "target": {"date": "2026-09-22T17:58:41.503000", "description": "Frozen timing reference 9c0a8921aa49 | independent confirmation", "fileName": "confirmed_timing_reference.tar.gz", "privateScore": "", "publicScore": "1535.2", "ref": 56471163, "status": "SubmissionStatus.COMPLETE"}, "target_status": "COMPLETE"}, "simulator_games": 0, "source_policy_sha256": "9c0a8921aa49fba080d53deee3c9fe8db7a8e2b02881e9adda4090af73e9c187", "stages": [{"elapsed_seconds": 5.104, "finished_utc": "2026-09-22T18:53:42.261247+00:00", "name": "offline_regression_tests", "started_utc": "2026-09-22T18:53:37.157654+00:00", "status": "PASS"}, {"elapsed_seconds": 0.11, "finished_utc": "2026-09-22T18:53:42.390505+00:00", "name": "verified_existing_workspace", "started_utc": "2026-09-22T18:53:42.280791+00:00", "status": "PASS"}, {"elapsed_seconds": 0.037, "finished_utc": "2026-09-22T18:53:42.446923+00:00", "name": "verified_prior_release_no_replay", "started_utc": "2026-09-22T18:53:42.409714+00:00", "status": "PASS"}, {"elapsed_seconds": 1.656, "finished_utc": "2026-09-22T18:53:44.129428+00:00", "name": "persisted_plotly_preflight", "started_utc": "2026-09-22T18:53:42.473130+00:00", "status": "PASS"}, {"elapsed_seconds": 0.604, "finished_utc": "2026-09-22T18:53:44.761757+00:00", "name": "existing_kaggle_cli", "started_utc": "2026-09-22T18:53:44.157913+00:00", "status": "PASS"}, {"elapsed_seconds": 0.222, "finished_utc": "2026-09-22T18:53:45.012619+00:00", "name": "expected_aws_account_and_bucket", "started_utc": "2026-09-22T18:53:44.790246+00:00", "status": "PASS"}, {"elapsed_seconds": 1.36, "finished_utc": "2026-09-22T18:53:46.400037+00:00", "name": "already_submitted_target_status", "started_utc": "2026-09-22T18:53:45.040359+00:00", "status": "PASS"}, {"elapsed_seconds": 28.69, "finished_utc": "2026-09-22T18:54:15.118514+00:00", "name": "new_target_public_episode_feedback", "started_utc": "2026-09-22T18:53:46.428392+00:00", "status": "PASS"}, {"elapsed_seconds": 3.029, "finished_utc": "2026-09-22T18:54:18.308933+00:00", "name": "existing_official_and_compact_ingestion", "started_utc": "2026-09-22T18:54:15.279627+00:00", "status": "PASS"}, {"elapsed_seconds": 10.147, "finished_utc": "2026-09-22T18:54:28.620985+00:00", "name": "missing_compact_files_only", "started_utc": "2026-09-22T18:54:18.473729+00:00", "status": "PASS"}, {"elapsed_seconds": 3.386, "finished_utc": "2026-09-22T18:54:32.174666+00:00", "name": "organizer_inventory_and_engine_drift", "started_utc": "2026-09-22T18:54:28.788832+00:00", "status": "PASS"}, {"elapsed_seconds": 17.72, "finished_utc": "2026-09-22T18:54:50.068888+00:00", "name": "broad_metadata_delta_only", "started_utc": "2026-09-22T18:54:32.349256+00:00", "status": "PASS"}, {"elapsed_seconds": 1.211, "finished_utc": "2026-09-22T18:54:51.462691+00:00", "name": "final_official_score_snapshot", "started_utc": "2026-09-22T18:54:50.252081+00:00", "status": "PASS"}, {"name": "executed_research_notebook", "started_utc": "2026-09-22T18:54:51.647337+00:00", "status": "RUNNING"}], "started_utc": "2026-09-22T18:53:37.139868+00:00", "status": "FEEDBACK_AND_DELTA_CAPTURED", "submission_attempted": false, "submission_ref": "56471163", "training_fits": 0, "updates": {"competition_files": {"complete": true, "metadata_only": true, "returned": 2}, "engine_modified": false, "errors": [], "full_announcements_verified": false, "latest_official_dataset": {"dataset": "kaggle/kaggriculture-episodes-2026-09-21", "date": "2026-09-21", "index_reported_payload_bytes": 21441470893, "listed_files": 639, "listing_complete": true, "payload_downloaded": false}, "limitation": "Inventories plus current official repository documents; not proof all discussion announcements are captured. A source difference triggers review, not an engine upgrade.", "sources": [{"differs_from_pinned_local": false, "executed": false, "fetched_utc": "2026-09-22T18:54:31.807152+00:00", "name": "AGENTS.md", "pinned_local_sha256": "e1a80501a7b02a212eaac9370ada4129a64e0ee6cb3cbc790f3d77d22863fe22", "sha256": "e1a80501a7b02a212eaac9370ada4129a64e0ee6cb3cbc790f3d77d22863fe22", "url": "https://raw.githubusercontent.com/Kaggle/kaggle-environments/master/kaggle_environments/envs/kaggriculture/AGENTS.md"}, {"differs_from_pinned_local": false, "executed": false, "fetched_utc": "2026-09-22T18:54:31.945427+00:00", "name": "README.md", "pinned_local_sha256": "3081e52baf8eb2da5d861acc63a3636ce29425f6bdb79a67036ba234ac4ade00", "sha256": "3081e52baf8eb2da5d861acc63a3636ce29425f6bdb79a67036ba234ac4ade00", "url": "https://raw.githubusercontent.com/Kaggle/kaggle-environments/master/kaggle_environments/envs/kaggriculture/README.md"}, {"differs_from_pinned_local": false, "executed": false, "fetched_utc": "2026-09-22T18:54:32.049596+00:00", "name": "kaggriculture.json", "pinned_local_sha256": "a82c89c1a2315b93f39775d8e025471a01b738647c9772658368ee6b1b6f4867", "sha256": "a82c89c1a2315b93f39775d8e025471a01b738647c9772658368ee6b1b6f4867", "url": "https://raw.githubusercontent.com/Kaggle/kaggle-environments/master/kaggle_environments/envs/kaggriculture/kaggriculture.json"}, {"differs_from_pinned_local": false, "executed": false, "fetched_utc": "2026-09-22T18:54:32.171544+00:00", "name": "kaggriculture.py", "pinned_local_sha256": "bc8a54879ef02c7ea64b8b333d6a976f0ea65c4949149d01f463f23bccee653e", "sha256": "bc8a54879ef02c7ea64b8b333d6a976f0ea65c4949149d01f463f23bccee653e", "url": "https://raw.githubusercontent.com/Kaggle/kaggle-environments/master/kaggle_environments/envs/kaggriculture/kaggriculture.py"}]}, "warnings": [], "workspace": {"branch": "main", "dirty": true, "discovery": "verified_previously_known_location", "examined": 1, "git_marker_kind": "directory", "head": "f86e79a46c40bed2fc1101b466691503efd3dbdf", "path": "/home/sagemaker-user/projects/kaggriculture", "remote_identity": "alvaromendizabal/kaggriculture", "status_porcelain": "?? docs/research/public_solution_reproduction_matrix.json\\n?? kaggriculture_frontier_data_s3_intake_patch.zip\\n?? notebooks/06_frontier_replay_corpus.ipynb\\n?? notebooks/28_live_replay_fidelity_audit.ipynb\\n?? notebooks/29_market_planner_experiment.ipynb\\n?? notebooks/30_complete_strategy_league.ipynb\\n?? notebooks/31_original_public_solution_reproduction.ipynb\\n?? notebooks/32_original_controller_benchmark.ipynb\\n?? notebooks/33_confirmed_release_and_public_data.ipynb\\n?? notebooks/34_data_coverage_and_live_progress.ipynb\\n?? notebooks/35_sixday_source_reproduction.ipynb\\n?? notebooks/36_sixday_native_benchmark.ipynb\\n?? notebooks/37_controller_component_fusion.ipynb\\n?? notebooks/38_counterfactual_route_learning.ipynb\\n?? notebooks/39_route_population_policy_improvement.ipynb\\n?? notebooks/40_future_shop_demand_scenarios.ipynb\\n?? notebooks/41_livestock_execution_fidelity.ipynb\\n?? notebooks/42_service_aware_cashflow_policy.ipynb\\n?? notebooks/43_constrained_service_route_synthesis.ipynb\\n?? notebooks/44_frozen_service_route_release.ipynb\\n?? notebooks/45_multiday_crop_program_synthesis.ipynb\\n?? notebooks/46_frontier_source_and_competitive_gap.ipynb\\n?? notebooks/47_frozen_public_reference_benchmark.ipynb\\n?? notebooks/48_frozen_timing_reference_confirmation.ipynb\\n?? reports/confirmed_release/\\n?? reports/controller_fusion/\\n?? reports/counterfactual_router/\\n?? reports/crop_programs/\\n?? reports/data_coverage/\\n?? reports/demand_scenarios/\\n?? reports/frontier_benchmark/\\n?? reports/frontier_daily_index.csv\\n?? reports/frontier_data_inventory.csv\\n?? reports/frontier_data_plan.json\\n?? reports/frontier_data_security_smoke.csv\\n?? reports/frontier_data_security_summary.json\\n?? reports/frontier_data_sources.csv\\n?? reports/frozen_release/\\n?? reports/live_replay_audit/\\n?? reports/livestock_fidelity/\\n?? reports/market_planner_experiment/\\n?? reports/original_controller_benchmark/\\n?? reports/reference_release/\\n?? reports/route_population/\\n?? reports/service_cashflow/\\n?? reports/service_routes/\\n?? reports/sixday_benchmark/\\n?? reports/sixday_source_gate/\\n?? reports/strategy_league/\\n?? src/kaggriculture_research/frontier_data.py"}}')
def show(fig):
 display({'application/vnd.plotly.v1+json':json.loads(fig.to_json())},raw=True)
C=D.get('coverage',{}); M=C.get('metadata',{}); S=D.get('score',{})
print(json.dumps({'submission':S.get('target'), 'compact_snapshot_latest':M.get('compact_latest'), 'official_index_latest':M.get('official_latest'), 'official_payload_bytes':M.get('official_reported_bytes'), 'compact_complete':C.get('all_listed_compact_files_retained',False)},indent=2))
# Out:
# {
#   "submission": {
#     "date": "2026-09-22T17:58:41.503000",
#     "description": "Frozen timing reference 9c0a8921aa49 | independent confirmation",
#     "fileName": "confirmed_timing_reference.tar.gz",
#     "privateScore": "",
#     "publicScore": "1535.2",
#     "ref": 56471163,
#     "status": "SubmissionStatus.COMPLETE"
#   },
#   "compact_snapshot_latest": "2026-09-20",
#   "official_index_latest": "2026-09-21",
#   "official_payload_bytes": 1150987125747,
#   "compact_complete": true
# }

# %% [markdown]
# ## Official rating snapshot
# The preview maximum below is labeled as such unless a rank-one row is present. It is not assumed to be complete standings. A newly validated score is not assumed to have converged.

# %%
target=S.get('target',{}) or {}; L=S.get('leaderboard',{}) or {}
values=[]; names=[]
for label,value in [('Confirmed controller — returned rating',target.get('publicScore')),('Best in returned submission list',(S.get('submissions',{}) or {}).get('best_in_returned_listing')),('Verified rank-one rating' if L.get('verified') else 'Maximum in returned leaderboard preview',L.get('leader_score',L.get('max_score_in_returned_rows')))]:
 try: values.append(float(value)); names.append(label)
 except (TypeError,ValueError): pass
fig=go.Figure(go.Bar(x=values,y=names,orientation='h'))
fig.update_layout(title='Official observations, not local win–tie scores',xaxis_title='Returned Kaggle rating',height=430,width=1000,margin=dict(l=310))
if not values: fig.add_annotation(text='No usable official score returned',showarrow=False,xref='paper',yref='paper',x=.5,y=.5)
show(fig)

# %% [markdown]
# ## Coverage ledger
# Raw-day coverage means the exact manifest identity is retained with a matching checksum receipt. Reused S3 objects are not re-downloaded merely to rehash them. The latest community snapshot can lag the organizer index.

# %%
expected=M.get('compact_days',0); kept=C.get('raw_daily_count',0)
processed=sum(x.get('delta_receipt_exists',False) for x in C.get('recent_delta_processing',[]))
fig=go.Figure(go.Bar(x=['Expected compact daily shards','Retained exact compact days','Recent delta extraction receipts'],y=[expected,kept,processed],text=[expected,kept,processed],textposition='auto'))
fig.update_layout(title='Retained raw data and processed recent data are different stages',yaxis_title='Daily shards / receipts',height=440,width=1020)
show(fig)
print('Remaining compact files:',[x['name'] for x in C.get('missing_after',[])])
print('All full organizer payloads retained:',False)
# Out:
# Remaining compact files: []
# All full organizer payloads retained: False

# %% [markdown]
# ## What the submitted controller does in its public games
# Each bar is a recorded result, not a simulated counterfactual. Missing or ambiguous seat identities are not imputed. The next research intervention should be grounded in these observations rather than stale baseline results.

# %%
rows=D.get('replays',[])
fig=go.Figure(go.Bar(x=[r['episode_id'] for r in rows],y=[r['cash_margin'] for r in rows],text=[r['outcome'] for r in rows],textposition='auto'))
fig.add_hline(y=0,line_dash='dash');fig.update_layout(title='Time-selected public games: confirmed controller cash differential',xaxis_title='Episode ID',yaxis_title='Candidate cash minus opponent cash',height=440,width=1000)
if not rows:fig.add_annotation(text='No public replay evidence acquired in this run',showarrow=False,xref='paper',yref='paper',x=.5,y=.5)
show(fig)
print(json.dumps({'updates':D.get('updates',{}),'broad_metadata':D.get('broad_metadata',{}),'episode_feedback_status':D.get('episode_feedback_status'),'warnings':D.get('warnings',[])},indent=2))
# Out:
# {
#   "updates": {
#     "competition_files": {
#       "complete": true,
#       "metadata_only": true,
#       "returned": 2
#     },
#     "engine_modified": false,
#     "errors": [],
#     "full_announcements_verified": false,
#     "latest_official_dataset": {
#       "dataset": "kaggle/kaggriculture-episodes-2026-09-21",
#       "date": "2026-09-21",
#       "index_reported_payload_bytes": 21441470893,
#       "listed_files": 639,
#       "listing_complete": true,
#       "payload_downloaded": false
#     },
#     "limitation": "Inventories plus current official repository documents; not proof all discussion announcements are captured. A source difference triggers review, not an engine upgrade.",
#     "sources": [
#       {
#         "differs_from_pinned_local": false,
#         "executed": false,
#         "fetched_utc": "2026-09-22T18:54:31.807152+00:00",
#         "name": "AGENTS.md",
# ...

# %% [markdown]
# ## Preserved confirmation: loss review, not another evaluation
# The frozen candidate won 50 of 64 direct games across 32 seed clusters. Both seats belong to the same cluster; 14 losses are not 14 independent seeds. The previously completed field panel contained related public baselines, not verified live leaderboard leaders. These observations can now motivate development, but cannot be reused as fresh validation.

# %%
local=D.get('local_diagnostics',{}); clusters=local.get('direct_seed_results',[])
fig=go.Figure(go.Bar(x=[str(r['seed']) for r in clusters],y=[r['margin'] for r in clusters]))
fig.add_hline(y=0,line_dash='dash'); fig.update_layout(title='Preserved direct confirmation: mean cash margin per seed',xaxis_title='Confirmation seed cluster (descriptive review only)',yaxis_title='Candidate minus incumbent coins',height=460,width=1100)
show(fig)
print(json.dumps({k:local.get(k) for k in ['direct_wins','direct_losses','direct_seed_clusters','losing_seed_clusters','cash_margin_mean','field']},indent=2))
# Out:
# {
#   "direct_wins": 50,
#   "direct_losses": 14,
#   "direct_seed_clusters": 32,
#   "losing_seed_clusters": 7,
#   "cash_margin_mean": 1302.015625,
#   "field": {
#     "sale_timing": {
#       "games": 192,
#       "losses": 146,
#       "wins": 46
#     },
#     "timing_current": {
#       "games": 192,
#       "losses": 26,
#       "wins": 166
#     }
#   }
# }

# %% [markdown]
# ## Decision
# Do not resubmit the same confirmed package. If the compact snapshot is complete, use its newest relevant-engine trajectories for targeted research; do not retrain on incompatible older engine versions. The organizer index and latest payload inventory expose—not hide—the much larger data gap. Downloading more data is not evidence of stronger actions.

# %%
assert D.get('submission_attempted') is False
assert D.get('training_fits',0)==0 and D.get('simulator_games',0)==0
print('NOTEBOOK_COMPLETE')
# Out:
# NOTEBOOK_COMPLETE
